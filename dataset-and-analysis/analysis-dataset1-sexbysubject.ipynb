# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Original Dataset Link : https://www.hesa.ac.uk/data-and-analysis/sb255/figure-13.csv --> renamed to 'dataset-1.csv'

# %%
df = pd.read_csv('dataset-1.csv')

# %%
df.head(100)
# Out:
#                 Subject Area First year marker Level of study Mode of study  \
# 0   (1) Medicine & dentistry               All            All     Full-time
# 1   (1) Medicine & dentistry               All            All     Full-time
# 2   (1) Medicine & dentistry               All            All     Full-time
# 3   (1) Medicine & dentistry               All            All     Full-time
# 4   (1) Medicine & dentistry               All            All     Full-time
# ..                       ...               ...            ...           ...
# 95  (1) Medicine & dentistry        First year            All     Full-time
# 96  (1) Medicine & dentistry        First year            All     Full-time
# 97  (1) Medicine & dentistry        First year            All     Full-time
# 98  (1) Medicine & dentistry        First year            All     Full-time
# 99  (1) Medicine & dentistry        First year            All     Full-time
#
#    Country of HE provider     Sex Academic Year  Number
# ...

# %% [markdown]
# # Trial : Calculate proportion of students in each sex, in 2014/15, and in UK

# %%
dfAllCountries14 = df[(df['First year marker'] == 'All') &
   (df['Mode of study'] == 'All') &
   (df['Country of HE provider'] == 'All') &
   (df['Academic Year'] == '2014/15') &
    (~df['Subject Area'].str.startswith('Total'))]

# %%
pivotDfAllCountries14 = dfAllCountries14.pivot_table('Number', ['Subject Area', 'Level of study'], 'Sex').reset_index()

# %%
pivotDfAllCountries14['Female (%)'] = (pivotDfAllCountries14['Female'] / pivotDfAllCountries14['Total']) * 100
pivotDfAllCountries14['Male (%)'] = (pivotDfAllCountries14['Male'] / pivotDfAllCountries14['Total']) * 100
pivotDfAllCountries14['Other (%)'] = (pivotDfAllCountries14['Other'] / pivotDfAllCountries14['Total']) * 100

# %%
pivotDfAllCountries14[pivotDfAllCountries14['Level of study']=='All postgraduate'].sort_values(by='Female (%)')
# Out:
# Sex                             Subject Area    Level of study  Female   Male  \
# 57              (9) Engineering & technology  All postgraduate    9335  30415
# 50                      (8) Computer science  All postgraduate    4270  12465
# 43                 (7) Mathematical sciences  All postgraduate    2165   4105
# 36                     (6) Physical sciences  All postgraduate    7920  11945
# 64     (A) Architecture, building & planning  All postgraduate    6190   8755
# 106   (G) Historical & philosophical studies  All postgraduate    8030   8305
# 85     (D) Business & administrative studies  All postgraduate   51795  51410
# 78                                   (C) Law  All postgraduate   10610   8825
# 1                   (1) Medicine & dentistry  All postgraduate   11780   8610
# 29        (5) Agriculture & related subjects  All postgraduate    2450   1625
# 71                        (B) Social studies  All postgraduate   30540  17845
# ...

# %% [markdown]
# # Calculate proportion of students in each sex, in 2018/19, and in UK

# %%
dfAllCountries18 = df[(df['First year marker'] == 'All') &
   (df['Mode of study'] == 'All') &
   (df['Country of HE provider'] == 'All') &
   (df['Academic Year'] == '2018/19') &
    (~df['Subject Area'].str.startswith('Total'))]

# %%
pivotDfAllCountries18 = dfAllCountries18.pivot_table('Number', ['Subject Area', 'Level of study'], 'Sex').reset_index()

# %%
pivotDfAllCountries18
# Out:
# Sex              Subject Area           Level of study  Female   Male  Other  \
# 0    (1) Medicine & dentistry                      All   40175  27485    100
# 1    (1) Medicine & dentistry         All postgraduate   12330   7715     75
# 2    (1) Medicine & dentistry        All undergraduate   27845  19765     25
# 3    (1) Medicine & dentistry             First degree   27595  19720     25
# 4    (1) Medicine & dentistry      Other undergraduate     255     50      0
# ..                        ...                      ...     ...    ...    ...
# 128              (J) Combined        All undergraduate   18880  11565     15
# 129              (J) Combined             First degree    9300   5470      0
# 130              (J) Combined      Other undergraduate    9580   6095     15
# 131              (J) Combined  Postgraduate (research)      10     10      0
# 132              (J) Combined    Postgraduate (taught)     865    425      0
#
# Sex  Total
# 0    67755
# 1    20120
# ...

# %%
pivotDfAllCountries18[pivotDfAllCountries18['Level of study']=='All postgraduate']
# Out:
# Sex                             Subject Area    Level of study  Female   Male  \
# 1                   (1) Medicine & dentistry  All postgraduate   12330   7715
# 8            (2) Subjects allied to medicine  All postgraduate   57145  19785
# 15                   (3) Biological sciences  All postgraduate   31775  14915
# 22                    (4) Veterinary science  All postgraduate    1685    720
# 29        (5) Agriculture & related subjects  All postgraduate    2275   1325
# 36                     (6) Physical sciences  All postgraduate    9170  12330
# 43                 (7) Mathematical sciences  All postgraduate    2655   4705
# 50                      (8) Computer science  All postgraduate    6235  15585
# 57              (9) Engineering & technology  All postgraduate    9870  28305
# 64     (A) Architecture, building & planning  All postgraduate    7750   9530
# 71                        (B) Social studies  All postgraduate   34605  18525
# ...

# %%
pivotDfAllCountries18['Female (%)'] = (pivotDfAllCountries18['Female'] / pivotDfAllCountries18['Total']) * 100
pivotDfAllCountries18['Male (%)'] = (pivotDfAllCountries18['Male'] / pivotDfAllCountries18['Total']) * 100
pivotDfAllCountries18['Other (%)'] = (pivotDfAllCountries18['Other'] / pivotDfAllCountries18['Total']) * 100

# %%
pivotDfAllCountries18[pivotDfAllCountries18['Level of study']=='All postgraduate']
# Out:
# Sex                             Subject Area    Level of study  Female   Male  \
# 1                   (1) Medicine & dentistry  All postgraduate   12330   7715
# 8            (2) Subjects allied to medicine  All postgraduate   57145  19785
# 15                   (3) Biological sciences  All postgraduate   31775  14915
# 22                    (4) Veterinary science  All postgraduate    1685    720
# 29        (5) Agriculture & related subjects  All postgraduate    2275   1325
# 36                     (6) Physical sciences  All postgraduate    9170  12330
# 43                 (7) Mathematical sciences  All postgraduate    2655   4705
# 50                      (8) Computer science  All postgraduate    6235  15585
# 57              (9) Engineering & technology  All postgraduate    9870  28305
# 64     (A) Architecture, building & planning  All postgraduate    7750   9530
# 71                        (B) Social studies  All postgraduate   34605  18525
# ...

# %%
pivotDfAllCountries18[pivotDfAllCountries18['Level of study']=='All postgraduate'].sort_values(by='Female (%)')
# Out:
# Sex                             Subject Area    Level of study  Female   Male  \
# 57              (9) Engineering & technology  All postgraduate    9870  28305
# 50                      (8) Computer science  All postgraduate    6235  15585
# 43                 (7) Mathematical sciences  All postgraduate    2655   4705
# 36                     (6) Physical sciences  All postgraduate    9170  12330
# 64     (A) Architecture, building & planning  All postgraduate    7750   9530
# 106   (G) Historical & philosophical studies  All postgraduate    8780   8105
# 85     (D) Business & administrative studies  All postgraduate   56870  51870
# 78                                   (C) Law  All postgraduate   12165   8390
# 1                   (1) Medicine & dentistry  All postgraduate   12330   7715
# 29        (5) Agriculture & related subjects  All postgraduate    2275   1325
# 71                        (B) Social studies  All postgraduate   34605  18525
# ...

# %%
pivotDfAllCountries18[pivotDfAllCountries18['Level of study']=='Postgraduate (research)'].sort_values(by='Female (%)')
# Out:
# Sex                             Subject Area           Level of study  Female  \
# 61              (9) Engineering & technology  Postgraduate (research)    3660
# 54                      (8) Computer science  Postgraduate (research)    1360
# 47                 (7) Mathematical sciences  Postgraduate (research)     910
# 40                     (6) Physical sciences  Postgraduate (research)    5120
# 68     (A) Architecture, building & planning  Postgraduate (research)     830
# 89     (D) Business & administrative studies  Postgraduate (research)    3105
# 110   (G) Historical & philosophical studies  Postgraduate (research)    3235
# 82                                   (C) Law  Postgraduate (research)    1120
# 75                        (B) Social studies  Postgraduate (research)    4520
# 33        (5) Agriculture & related subjects  Postgraduate (research)     475
# 117               (H) Creative arts & design  Postgraduate (research)    2265
# ...

# %%
pivotDfAllCountries18[pivotDfAllCountries18['Level of study']=='All undergraduate'].sort_values(by='Female (%)')
# Out:
# Sex                             Subject Area     Level of study  Female  \
# 51                      (8) Computer science  All undergraduate   14845
# 58              (9) Engineering & technology  All undergraduate   21710
# 65     (A) Architecture, building & planning  All undergraduate   13575
# 44                 (7) Mathematical sciences  All undergraduate   14410
# 37                     (6) Physical sciences  All undergraduate   31860
# 86     (D) Business & administrative studies  All undergraduate  119840
# 107   (G) Historical & philosophical studies  All undergraduate   36150
# 93   (E) Mass communications & documentation  All undergraduate   21720
# 2                   (1) Medicine & dentistry  All undergraduate   27845
# 128                             (J) Combined  All undergraduate   18880
# 72                        (B) Social studies  All undergraduate  116545
# 16                   (3) Biological sciences  All undergraduate  125090
# ...

# %%
pivotDfAllCountries18[pivotDfAllCountries18['Level of study']=='Other undergraduate'].sort_values(by='Female (%)')
# Out:
# Sex                             Subject Area       Level of study  Female  \
# 60              (9) Engineering & technology  Other undergraduate    1020
# 53                      (8) Computer science  Other undergraduate     650
# 67     (A) Architecture, building & planning  Other undergraduate     975
# 46                 (7) Mathematical sciences  Other undergraduate     180
# 95   (E) Mass communications & documentation  Other undergraduate     205
# 39                     (6) Physical sciences  Other undergraduate     865
# 88     (D) Business & administrative studies  Other undergraduate    6160
# 109   (G) Historical & philosophical studies  Other undergraduate    1270
# 18                   (3) Biological sciences  Other undergraduate    3850
# 102                            (F) Languages  Other undergraduate    5200
# 32        (5) Agriculture & related subjects  Other undergraduate    3095
# 130                             (J) Combined  Other undergraduate    9580
# ...

# %% [markdown]
# # UK : Finding average change in proportion of students in each sex over 5-year period, categorised by subject area and level of study
# (*not change in exact number of students!)
#
# ## Started by calculate proportion of students in each sex over 5-year period in UK

# %%
dfAllCountries = df[(df['First year marker'] == 'All') &
   (df['Mode of study'] == 'All') &
   (df['Country of HE provider'] == 'All') &
    (~df['Subject Area'].str.startswith('Total'))]

# %%
dfAllCountries
# Out:
#                     Subject Area First year marker     Level of study  \
# 720     (1) Medicine & dentistry               All                All
# 721     (1) Medicine & dentistry               All                All
# 722     (1) Medicine & dentistry               All                All
# 723     (1) Medicine & dentistry               All                All
# 724     (1) Medicine & dentistry               All                All
# ...                          ...               ...                ...
# 121615              (J) Combined               All  All undergraduate
# 121616              (J) Combined               All  All undergraduate
# 121617              (J) Combined               All  All undergraduate
# 121618              (J) Combined               All  All undergraduate
# 121619              (J) Combined               All  All undergraduate
#
#        Mode of study Country of HE provider     Sex Academic Year  Number
# ...

# %%
pivotDfAllCountries = dfAllCountries.pivot_table('Number', ['Subject Area', 'Level of study', 'Academic Year'], 'Sex').reset_index()

# %%
pivotDfAllCountries
# Out:
# Sex              Subject Area         Level of study Academic Year  Female  \
# 0    (1) Medicine & dentistry                    All       2014/15   37335
# 1    (1) Medicine & dentistry                    All       2015/16   37415
# 2    (1) Medicine & dentistry                    All       2016/17   37430
# 3    (1) Medicine & dentistry                    All       2017/18   38340
# 4    (1) Medicine & dentistry                    All       2018/19   40175
# ..                        ...                    ...           ...     ...
# 660              (J) Combined  Postgraduate (taught)       2014/15    1250
# 661              (J) Combined  Postgraduate (taught)       2015/16    1100
# 662              (J) Combined  Postgraduate (taught)       2016/17     915
# 663              (J) Combined  Postgraduate (taught)       2017/18     875
# 664              (J) Combined  Postgraduate (taught)       2018/19     865
#
# Sex   Male  Other  Total
# 0    28660      5  66000
# ...

# %%
pd.set_option('display.max_rows', 50)
pd.set_option('display.max_columns', 500)

# %%
pivotDfAllCountriesAllYear = pivotDfAllCountries.pivot_table(['Female','Male','Other',
                                'Total'], ['Subject Area', 'Level of study'], 'Academic Year').reset_index()

# %%
pivotDfAllCountries['Female (%)'] = (pivotDfAllCountries['Female'] / pivotDfAllCountries['Total']) * 100
pivotDfAllCountries['Male (%)'] = (pivotDfAllCountries['Male'] / pivotDfAllCountries['Total']) * 100
pivotDfAllCountries['Other (%)'] = (pivotDfAllCountries['Other'] / pivotDfAllCountries['Total']) * 100

# %%
pivotDfAllCountries[pivotDfAllCountries['Level of study']=='All postgraduate']
# Out:
# Sex              Subject Area    Level of study Academic Year  Female  Male  \
# 5    (1) Medicine & dentistry  All postgraduate       2014/15   11780  8610
# 6    (1) Medicine & dentistry  All postgraduate       2015/16   11905  8400
# 7    (1) Medicine & dentistry  All postgraduate       2016/17   11725  8025
# 8    (1) Medicine & dentistry  All postgraduate       2017/18   11915  7955
# 9    (1) Medicine & dentistry  All postgraduate       2018/19   12330  7715
# ..                        ...               ...           ...     ...   ...
# 635              (J) Combined  All postgraduate       2014/15    1255   665
# 636              (J) Combined  All postgraduate       2015/16    1115   680
# 637              (J) Combined  All postgraduate       2016/17     925   520
# 638              (J) Combined  All postgraduate       2017/18     895   460
# 639              (J) Combined  All postgraduate       2018/19     870   435
#
# Sex  Other  Total  Female (%)   Male (%)  Other (%)
# ...

# %%
pivotDfAllCountriesAllYear
# Out:
# Sex                        Subject Area           Level of study  Female  \
# Academic Year                                                    2014/15
# 0              (1) Medicine & dentistry                      All   37335
# 1              (1) Medicine & dentistry         All postgraduate   11780
# 2              (1) Medicine & dentistry        All undergraduate   25555
# 3              (1) Medicine & dentistry             First degree   25170
# 4              (1) Medicine & dentistry      Other undergraduate     385
# ..                                  ...                      ...     ...
# 128                        (J) Combined        All undergraduate   29025
# 129                        (J) Combined             First degree   14830
# 130                        (J) Combined      Other undergraduate   14195
# 131                        (J) Combined  Postgraduate (research)       5
# 132                        (J) Combined    Postgraduate (taught)    1250
#
# ...

# %% [markdown]
# ## Then calculate 'average change' in proportion of students in each sex over 5-year period

# %%
pivotDfAllCountriesAllYearPercent = pivotDfAllCountriesAllYear.copy()

# %%
pivotDfAllCountriesAllYearPercent
# Out:
# Sex                        Subject Area           Level of study  Female  \
# Academic Year                                                    2014/15
# 0              (1) Medicine & dentistry                      All   37335
# 1              (1) Medicine & dentistry         All postgraduate   11780
# 2              (1) Medicine & dentistry        All undergraduate   25555
# 3              (1) Medicine & dentistry             First degree   25170
# 4              (1) Medicine & dentistry      Other undergraduate     385
# ..                                  ...                      ...     ...
# 128                        (J) Combined        All undergraduate   29025
# 129                        (J) Combined             First degree   14830
# 130                        (J) Combined      Other undergraduate   14195
# 131                        (J) Combined  Postgraduate (research)       5
# 132                        (J) Combined    Postgraduate (taught)    1250
#
# ...

# %%
pivotDfAllCountriesAllYearPercent['Female (%) 2014/15'] = (pivotDfAllCountriesAllYearPercent['Female']['2014/15'] / pivotDfAllCountriesAllYearPercent['Total']['2014/15']) * 100
pivotDfAllCountriesAllYearPercent['Male (%) 2014/15'] = (pivotDfAllCountriesAllYearPercent['Male']['2014/15'] / pivotDfAllCountriesAllYearPercent['Total']['2014/15']) * 100
pivotDfAllCountriesAllYearPercent['Other (%) 2014/15'] = (pivotDfAllCountriesAllYearPercent['Other']['2014/15'] / pivotDfAllCountriesAllYearPercent['Total']['2014/15']) * 100
pivotDfAllCountriesAllYearPercent['Female (%) 2015/16'] = (pivotDfAllCountriesAllYearPercent['Female']['2015/16'] / pivotDfAllCountriesAllYearPercent['Total']['2015/16']) * 100
pivotDfAllCountriesAllYearPercent['Male (%) 2015/16'] = (pivotDfAllCountriesAllYearPercent['Male']['2015/16'] / pivotDfAllCountriesAllYearPercent['Total']['2015/16']) * 100
pivotDfAllCountriesAllYearPercent['Other (%) 2015/16'] = (pivotDfAllCountriesAllYearPercent['Other']['2015/16'] / pivotDfAllCountriesAllYearPercent['Total']['2015/16']) * 100
pivotDfAllCountriesAllYearPercent['Female (%) 2016/17'] = (pivotDfAllCountriesAllYearPercent['Female']['2016/17'] / pivotDfAllCountriesAllYearPercent['Total']['2016/17']) * 100
pivotDfAllCountriesAllYearPercent['Male (%) 2016/17'] = (pivotDfAllCountriesAllYearPercent['Male']['2016/17'] / pivotDfAllCountriesAllYearPercent['Total']['2016/17']) * 100
pivotDfAllCountriesAllYearPercent['Other (%) 2016/17'] = (pivotDfAllCountriesAllYearPercent['Other']['2016/17'] / pivotDfAllCountriesAllYearPercent['Total']['2016/17']) * 100
pivotDfAllCountriesAllYearPercent['Female (%) 2017/18'] = (pivotDfAllCountriesAllYearPercent['Female']['2017/18'] / pivotDfAllCountriesAllYearPercent['Total']['2017/18']) * 100
pivotDfAllCountriesAllYearPercent['Male (%) 2017/18'] = (pivotDfAllCountriesAllYearPercent['Male']['2017/18'] / pivotDfAllCountriesAllYearPercent['Total']['2017/18']) * 100
pivotDfAllCountriesAllYearPercent['Other (%) 2017/18'] = (pivotDfAllCountriesAllYearPercent['Other']['2017/18'] / pivotDfAllCountriesAllYearPercent['Total']['2017/18']) * 100
pivotDfAllCountriesAllYearPercent['Female (%) 2018/19'] = (pivotDfAllCountriesAllYearPercent['Female']['2018/19'] / pivotDfAllCountriesAllYearPercent['Total']['2018/19']) * 100
pivotDfAllCountriesAllYearPercent['Male (%) 2018/19'] = (pivotDfAllCountriesAllYearPercent['Male']['2018/19'] / pivotDfAllCountriesAllYearPercent['Total']['2018/19']) * 100
pivotDfAllCountriesAllYearPercent['Other (%) 2018/19'] = (pivotDfAllCountriesAllYearPercent['Other']['2018/19'] / pivotDfAllCountriesAllYearPercent['Total']['2018/19']) * 100

# %%
pivotDfAllCountriesAllYearPercent
# Out:
# Sex                        Subject Area           Level of study  Female  \
# Academic Year                                                    2014/15
# 0              (1) Medicine & dentistry                      All   37335
# 1              (1) Medicine & dentistry         All postgraduate   11780
# 2              (1) Medicine & dentistry        All undergraduate   25555
# 3              (1) Medicine & dentistry             First degree   25170
# 4              (1) Medicine & dentistry      Other undergraduate     385
# ..                                  ...                      ...     ...
# 128                        (J) Combined        All undergraduate   29025
# 129                        (J) Combined             First degree   14830
# 130                        (J) Combined      Other undergraduate   14195
# 131                        (J) Combined  Postgraduate (research)       5
# 132                        (J) Combined    Postgraduate (taught)    1250
#
# ...

# %%
pivotDfAllCountriesAllYearPercent = pivotDfAllCountriesAllYearPercent.drop(columns=['Female','Male','Other','Total'])
# Out:
# /Users/pasitk/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:3946: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   new_axis = axis.drop(labels, errors=errors)

# %%
pivotDfAllCountriesAllYearPercent['Avg. % Change of Female'] = ((pivotDfAllCountriesAllYearPercent['Female (%) 2015/16'] - pivotDfAllCountriesAllYearPercent['Female (%) 2014/15']) +
                                                                (pivotDfAllCountriesAllYearPercent['Female (%) 2016/17'] - pivotDfAllCountriesAllYearPercent['Female (%) 2015/16']) +
                                                                (pivotDfAllCountriesAllYearPercent['Female (%) 2017/18'] - pivotDfAllCountriesAllYearPercent['Female (%) 2016/17']) +
                                                                (pivotDfAllCountriesAllYearPercent['Female (%) 2018/19'] - pivotDfAllCountriesAllYearPercent['Female (%) 2017/18'])) / 4
pivotDfAllCountriesAllYearPercent['Avg. % Change of Male'] = ((pivotDfAllCountriesAllYearPercent['Male (%) 2015/16'] - pivotDfAllCountriesAllYearPercent['Male (%) 2014/15']) +
                                                                (pivotDfAllCountriesAllYearPercent['Male (%) 2016/17'] - pivotDfAllCountriesAllYearPercent['Male (%) 2015/16']) +
                                                                (pivotDfAllCountriesAllYearPercent['Male (%) 2017/18'] - pivotDfAllCountriesAllYearPercent['Male (%) 2016/17']) +
                                                                (pivotDfAllCountriesAllYearPercent['Male (%) 2018/19'] - pivotDfAllCountriesAllYearPercent['Male (%) 2017/18'])) / 4
pivotDfAllCountriesAllYearPercent['Avg. % Change of Other'] = ((pivotDfAllCountriesAllYearPercent['Other (%) 2015/16'] - pivotDfAllCountriesAllYearPercent['Other (%) 2014/15']) +
                                                                (pivotDfAllCountriesAllYearPercent['Other (%) 2016/17'] - pivotDfAllCountriesAllYearPercent['Other (%) 2015/16']) +
                                                                (pivotDfAllCountriesAllYearPercent['Other (%) 2017/18'] - pivotDfAllCountriesAllYearPercent['Other (%) 2016/17']) +
                                                                (pivotDfAllCountriesAllYearPercent['Other (%) 2018/19'] - pivotDfAllCountriesAllYearPercent['Other (%) 2017/18'])) / 4

# %%
pivotDfAllCountriesAllYearAvgPercentChg =  pivotDfAllCountriesAllYearPercent.drop(columns=[
    'Female (%) 2014/15', 'Female (%) 2015/16', 'Female (%) 2016/17', 'Female (%) 2017/18', 'Female (%) 2018/19',
    'Male (%) 2014/15', 'Male (%) 2015/16', 'Male (%) 2016/17', 'Male (%) 2017/18', 'Male (%) 2018/19',
    'Other (%) 2014/15', 'Other (%) 2015/16', 'Other (%) 2016/17', 'Other (%) 2017/18', 'Other (%) 2018/19',
])

# %%
pivotDfAllCountriesAllYearAvgPercentChg[pivotDfAllCountriesAllYearAvgPercentChg['Level of study'] == 'All'].sort_values(by='Avg. % Change of Female', ascending=False)
# Out:
# Sex                                       Subject Area Level of study  \
# Academic Year
# 28                  (5) Agriculture & related subjects            All
# 14                             (3) Biological sciences            All
# 35                               (6) Physical sciences            All
# 77                                             (C) Law            All
# 0                             (1) Medicine & dentistry            All
# 63               (A) Architecture, building & planning            All
# 56                        (9) Engineering & technology            All
# 119                                      (I) Education            All
# 98                                       (F) Languages            All
# 105             (G) Historical & philosophical studies            All
# 21                              (4) Veterinary science            All
# 112                         (H) Creative arts & design            All
# ...

# %% [markdown]
# # England : Finding average change in proportion of students in each sex over 5-year period, categorised by subject area and level of study
# (*not change in exact number of students!)
#
# ## Started by calculate proportion of students in each sex over 5-year period in England

# %%
dfEngland = df[(df['First year marker'] == 'All') &
   (df['Mode of study'] == 'All') &
   (df['Country of HE provider'] == 'England') &
    (~df['Subject Area'].str.startswith('Total'))]

# %%
dfEngland
# Out:
#                     Subject Area First year marker     Level of study  \
# 480     (1) Medicine & dentistry               All                All
# 481     (1) Medicine & dentistry               All                All
# 482     (1) Medicine & dentistry               All                All
# 483     (1) Medicine & dentistry               All                All
# 484     (1) Medicine & dentistry               All                All
# ...                          ...               ...                ...
# 121375              (J) Combined               All  All undergraduate
# 121376              (J) Combined               All  All undergraduate
# 121377              (J) Combined               All  All undergraduate
# 121378              (J) Combined               All  All undergraduate
# 121379              (J) Combined               All  All undergraduate
#
#        Mode of study Country of HE provider     Sex Academic Year  Number
# ...

# %%
dfEngland['Subject Area'].unique()
# Out:
# array(['(1) Medicine & dentistry', '(2) Subjects allied to medicine',
#        '(3) Biological sciences', '(4) Veterinary science',
#        '(5) Agriculture & related subjects', '(6) Physical sciences',
#        '(7) Mathematical sciences', '(8) Computer science',
#        '(9) Engineering & technology',
#        '(A) Architecture, building & planning', '(B) Social studies',
#        '(C) Law', '(D) Business & administrative studies',
#        '(E) Mass communications & documentation', '(F) Languages',
#        '(G) Historical & philosophical studies',
#        '(H) Creative arts & design', '(I) Education', '(J) Combined'],
#       dtype=object)

# %%
dfEngland[dfEngland['Subject Area'] == '(2) Subjects allied to medicine']
# Out:
#                           Subject Area First year marker     Level of study  \
# 6640   (2) Subjects allied to medicine               All                All
# 6641   (2) Subjects allied to medicine               All                All
# 6642   (2) Subjects allied to medicine               All                All
# 6643   (2) Subjects allied to medicine               All                All
# 6644   (2) Subjects allied to medicine               All                All
# ...                                ...               ...                ...
# 12055  (2) Subjects allied to medicine               All  All undergraduate
# 12056  (2) Subjects allied to medicine               All  All undergraduate
# 12057  (2) Subjects allied to medicine               All  All undergraduate
# 12058  (2) Subjects allied to medicine               All  All undergraduate
# 12059  (2) Subjects allied to medicine               All  All undergraduate
#
# ...

# %%
dfEngland.count()
# Out:
# Subject Area              2660
# First year marker         2660
# Level of study            2660
# Mode of study             2660
# Country of HE provider    2660
# Sex                       2660
# Academic Year             2660
# Number                    2660
# dtype: int64

# %%
pivotDfEngland = dfEngland.pivot_table('Number', ['Subject Area', 'Level of study', 'Academic Year'], 'Sex').reset_index()

# %%
pivotDfEnglandAllYear = pivotDfEngland.pivot_table(['Female','Male','Other',
                                'Total'], ['Subject Area', 'Level of study'], 'Academic Year').reset_index()

# %%
pivotDfEngland['Female (%)'] = (pivotDfEngland['Female'] / pivotDfEngland['Total']) * 100
pivotDfEngland['Male (%)'] = (pivotDfEngland['Male'] / pivotDfEngland['Total']) * 100
pivotDfEngland['Other (%)'] = (pivotDfEngland['Other'] / pivotDfEngland['Total']) * 100

# %%
pivotDfEngland[pivotDfEngland['Level of study']=='All postgraduate']
# Out:
# Sex              Subject Area    Level of study Academic Year  Female  Male  \
# 5    (1) Medicine & dentistry  All postgraduate       2014/15    9410  6925
# 6    (1) Medicine & dentistry  All postgraduate       2015/16    9605  6915
# 7    (1) Medicine & dentistry  All postgraduate       2016/17    9545  6680
# 8    (1) Medicine & dentistry  All postgraduate       2017/18    9690  6645
# 9    (1) Medicine & dentistry  All postgraduate       2018/19   10135  6490
# ..                        ...               ...           ...     ...   ...
# 635              (J) Combined  All postgraduate       2014/15     830   455
# 636              (J) Combined  All postgraduate       2015/16     835   495
# 637              (J) Combined  All postgraduate       2016/17     730   350
# 638              (J) Combined  All postgraduate       2017/18     725   340
# 639              (J) Combined  All postgraduate       2018/19     635   310
#
# Sex  Other  Total  Female (%)   Male (%)  Other (%)
# ...

# %% [markdown]
# ## Then calculate 'average change' in proportion of students in each sex over 5-year period

# %%
pivotDfEnglandAllYearPercent = pivotDfEnglandAllYear.copy()

# %%
pivotDfEnglandAllYearPercent['Female (%) 2014/15'] = (pivotDfEnglandAllYearPercent['Female']['2014/15'] / pivotDfEnglandAllYearPercent['Total']['2014/15']) * 100
pivotDfEnglandAllYearPercent['Male (%) 2014/15'] = (pivotDfEnglandAllYearPercent['Male']['2014/15'] / pivotDfEnglandAllYearPercent['Total']['2014/15']) * 100
pivotDfEnglandAllYearPercent['Other (%) 2014/15'] = (pivotDfEnglandAllYearPercent['Other']['2014/15'] / pivotDfEnglandAllYearPercent['Total']['2014/15']) * 100
pivotDfEnglandAllYearPercent['Female (%) 2015/16'] = (pivotDfEnglandAllYearPercent['Female']['2015/16'] / pivotDfEnglandAllYearPercent['Total']['2015/16']) * 100
pivotDfEnglandAllYearPercent['Male (%) 2015/16'] = (pivotDfEnglandAllYearPercent['Male']['2015/16'] / pivotDfEnglandAllYearPercent['Total']['2015/16']) * 100
pivotDfEnglandAllYearPercent['Other (%) 2015/16'] = (pivotDfEnglandAllYearPercent['Other']['2015/16'] / pivotDfEnglandAllYearPercent['Total']['2015/16']) * 100
pivotDfEnglandAllYearPercent['Female (%) 2016/17'] = (pivotDfEnglandAllYearPercent['Female']['2016/17'] / pivotDfEnglandAllYearPercent['Total']['2016/17']) * 100
pivotDfEnglandAllYearPercent['Male (%) 2016/17'] = (pivotDfEnglandAllYearPercent['Male']['2016/17'] / pivotDfEnglandAllYearPercent['Total']['2016/17']) * 100
pivotDfEnglandAllYearPercent['Other (%) 2016/17'] = (pivotDfEnglandAllYearPercent['Other']['2016/17'] / pivotDfEnglandAllYearPercent['Total']['2016/17']) * 100
pivotDfEnglandAllYearPercent['Female (%) 2017/18'] = (pivotDfEnglandAllYearPercent['Female']['2017/18'] / pivotDfEnglandAllYearPercent['Total']['2017/18']) * 100
pivotDfEnglandAllYearPercent['Male (%) 2017/18'] = (pivotDfEnglandAllYearPercent['Male']['2017/18'] / pivotDfEnglandAllYearPercent['Total']['2017/18']) * 100
pivotDfEnglandAllYearPercent['Other (%) 2017/18'] = (pivotDfEnglandAllYearPercent['Other']['2017/18'] / pivotDfEnglandAllYearPercent['Total']['2017/18']) * 100
pivotDfEnglandAllYearPercent['Female (%) 2018/19'] = (pivotDfEnglandAllYearPercent['Female']['2018/19'] / pivotDfEnglandAllYearPercent['Total']['2018/19']) * 100
pivotDfEnglandAllYearPercent['Male (%) 2018/19'] = (pivotDfEnglandAllYearPercent['Male']['2018/19'] / pivotDfEnglandAllYearPercent['Total']['2018/19']) * 100
pivotDfEnglandAllYearPercent['Other (%) 2018/19'] = (pivotDfEnglandAllYearPercent['Other']['2018/19'] / pivotDfEnglandAllYearPercent['Total']['2018/19']) * 100

# %%
pivotDfEnglandAllYearPercent = pivotDfEnglandAllYearPercent.drop(columns=['Female','Male','Other','Total'])

# %%
pivotDfEnglandAllYearPercent['Avg. % Change of Female'] = ((pivotDfEnglandAllYearPercent['Female (%) 2015/16'] - pivotDfEnglandAllYearPercent['Female (%) 2014/15']) +
                                                                (pivotDfEnglandAllYearPercent['Female (%) 2016/17'] - pivotDfEnglandAllYearPercent['Female (%) 2015/16']) +
                                                                (pivotDfEnglandAllYearPercent['Female (%) 2017/18'] - pivotDfEnglandAllYearPercent['Female (%) 2016/17']) +
                                                                (pivotDfEnglandAllYearPercent['Female (%) 2018/19'] - pivotDfEnglandAllYearPercent['Female (%) 2017/18'])) / 4
pivotDfEnglandAllYearPercent['Avg. % Change of Male'] = ((pivotDfEnglandAllYearPercent['Male (%) 2015/16'] - pivotDfEnglandAllYearPercent['Male (%) 2014/15']) +
                                                                (pivotDfEnglandAllYearPercent['Male (%) 2016/17'] - pivotDfEnglandAllYearPercent['Male (%) 2015/16']) +
                                                                (pivotDfEnglandAllYearPercent['Male (%) 2017/18'] - pivotDfEnglandAllYearPercent['Male (%) 2016/17']) +
                                                                (pivotDfEnglandAllYearPercent['Male (%) 2018/19'] - pivotDfEnglandAllYearPercent['Male (%) 2017/18'])) / 4
pivotDfEnglandAllYearPercent['Avg. % Change of Other'] = ((pivotDfEnglandAllYearPercent['Other (%) 2015/16'] - pivotDfEnglandAllYearPercent['Other (%) 2014/15']) +
                                                                (pivotDfEnglandAllYearPercent['Other (%) 2016/17'] - pivotDfEnglandAllYearPercent['Other (%) 2015/16']) +
                                                                (pivotDfEnglandAllYearPercent['Other (%) 2017/18'] - pivotDfEnglandAllYearPercent['Other (%) 2016/17']) +
                                                                (pivotDfEnglandAllYearPercent['Other (%) 2018/19'] - pivotDfEnglandAllYearPercent['Other (%) 2017/18'])) / 4

# %%
pivotDfEnglandAllYearAvgPercentChg =  pivotDfEnglandAllYearPercent.drop(columns=[
    'Female (%) 2014/15', 'Female (%) 2015/16', 'Female (%) 2016/17', 'Female (%) 2017/18', 'Female (%) 2018/19',
    'Male (%) 2014/15', 'Male (%) 2015/16', 'Male (%) 2016/17', 'Male (%) 2017/18', 'Male (%) 2018/19',
    'Other (%) 2014/15', 'Other (%) 2015/16', 'Other (%) 2016/17', 'Other (%) 2017/18', 'Other (%) 2018/19',
])

# %%
pivotDfEnglandAllYearAvgPercentChg[pivotDfEnglandAllYearAvgPercentChg['Level of study'] == 'All'].sort_values(by='Avg. % Change of Female', ascending=False)
# Out:
# Sex                                       Subject Area Level of study  \
# Academic Year
# 28                  (5) Agriculture & related subjects            All
# 14                             (3) Biological sciences            All
# 35                               (6) Physical sciences            All
# 77                                             (C) Law            All
# 63               (A) Architecture, building & planning            All
# 56                        (9) Engineering & technology            All
# 0                             (1) Medicine & dentistry            All
# 98                                       (F) Languages            All
# 119                                      (I) Education            All
# 126                                       (J) Combined            All
# 112                         (H) Creative arts & design            All
# 105             (G) Historical & philosophical studies            All
# ...

# %% [markdown]
# # Wales : Finding average change in proportion of students in each sex over 5-year period, categorised by subject area and level of study
# (*not change in exact number of students!)
#
# ## Started by calculate proportion of students in each sex over 5-year period in Wales

# %%
dfWales = df[(df['First year marker'] == 'All') &
   (df['Mode of study'] == 'All') &
   (df['Country of HE provider'] == 'Wales') &
    (~df['Subject Area'].str.startswith('Total'))]

# %%
dfWales
# Out:
#                     Subject Area First year marker     Level of study  \
# 540     (1) Medicine & dentistry               All                All
# 541     (1) Medicine & dentistry               All                All
# 542     (1) Medicine & dentistry               All                All
# 543     (1) Medicine & dentistry               All                All
# 544     (1) Medicine & dentistry               All                All
# ...                          ...               ...                ...
# 121435              (J) Combined               All  All undergraduate
# 121436              (J) Combined               All  All undergraduate
# 121437              (J) Combined               All  All undergraduate
# 121438              (J) Combined               All  All undergraduate
# 121439              (J) Combined               All  All undergraduate
#
#        Mode of study Country of HE provider     Sex Academic Year  Number
# ...

# %%
pivotDfWales = dfWales.pivot_table(
    'Number', ['Subject Area', 'Level of study', 'Academic Year'], 'Sex').reset_index()

# %%
pivotDfWalesAllYear = pivotDfWales.pivot_table(['Female','Male','Other',
                                'Total'], ['Subject Area', 'Level of study'], 'Academic Year').reset_index()

# %%
pivotDfWales['Female (%)'] = (pivotDfWales['Female'] / pivotDfWales['Total']) * 100
pivotDfWales['Male (%)'] = (pivotDfWales['Male'] / pivotDfWales['Total']) * 100
pivotDfWales['Other (%)'] = (pivotDfWales['Other'] / pivotDfWales['Total']) * 100

# %%
pivotDfWales
# Out:
# Sex              Subject Area         Level of study Academic Year  Female  \
# 0    (1) Medicine & dentistry                    All       2014/15    2275
# 1    (1) Medicine & dentistry                    All       2015/16    2185
# 2    (1) Medicine & dentistry                    All       2016/17    2130
# 3    (1) Medicine & dentistry                    All       2017/18    2030
# 4    (1) Medicine & dentistry                    All       2018/19    2080
# ..                        ...                    ...           ...     ...
# 620              (J) Combined  Postgraduate (taught)       2014/15     125
# 621              (J) Combined  Postgraduate (taught)       2015/16      40
# 622              (J) Combined  Postgraduate (taught)       2016/17       5
# 623              (J) Combined  Postgraduate (taught)       2017/18      10
# 624              (J) Combined  Postgraduate (taught)       2018/19      35
#
# Sex  Male  Other  Total  Female (%)   Male (%)  Other (%)
# ...

# %% [markdown]
# ## Then calculate 'average change' in proportion of students in each sex over 5-year period

# %%
pivotDfWalesAllYearPercent = pivotDfWalesAllYear.copy()

# %%
pivotDfWalesAllYearPercent['Female (%) 2014/15'] = (pivotDfWalesAllYearPercent['Female']['2014/15'] / pivotDfWalesAllYearPercent['Total']['2014/15']) * 100
pivotDfWalesAllYearPercent['Male (%) 2014/15'] = (pivotDfWalesAllYearPercent['Male']['2014/15'] / pivotDfWalesAllYearPercent['Total']['2014/15']) * 100
pivotDfWalesAllYearPercent['Other (%) 2014/15'] = (pivotDfWalesAllYearPercent['Other']['2014/15'] / pivotDfWalesAllYearPercent['Total']['2014/15']) * 100
pivotDfWalesAllYearPercent['Female (%) 2015/16'] = (pivotDfWalesAllYearPercent['Female']['2015/16'] / pivotDfWalesAllYearPercent['Total']['2015/16']) * 100
pivotDfWalesAllYearPercent['Male (%) 2015/16'] = (pivotDfWalesAllYearPercent['Male']['2015/16'] / pivotDfWalesAllYearPercent['Total']['2015/16']) * 100
pivotDfWalesAllYearPercent['Other (%) 2015/16'] = (pivotDfWalesAllYearPercent['Other']['2015/16'] / pivotDfWalesAllYearPercent['Total']['2015/16']) * 100
pivotDfWalesAllYearPercent['Female (%) 2016/17'] = (pivotDfWalesAllYearPercent['Female']['2016/17'] / pivotDfWalesAllYearPercent['Total']['2016/17']) * 100
pivotDfWalesAllYearPercent['Male (%) 2016/17'] = (pivotDfWalesAllYearPercent['Male']['2016/17'] / pivotDfWalesAllYearPercent['Total']['2016/17']) * 100
pivotDfWalesAllYearPercent['Other (%) 2016/17'] = (pivotDfWalesAllYearPercent['Other']['2016/17'] / pivotDfWalesAllYearPercent['Total']['2016/17']) * 100
pivotDfWalesAllYearPercent['Female (%) 2017/18'] = (pivotDfWalesAllYearPercent['Female']['2017/18'] / pivotDfWalesAllYearPercent['Total']['2017/18']) * 100
pivotDfWalesAllYearPercent['Male (%) 2017/18'] = (pivotDfWalesAllYearPercent['Male']['2017/18'] / pivotDfWalesAllYearPercent['Total']['2017/18']) * 100
pivotDfWalesAllYearPercent['Other (%) 2017/18'] = (pivotDfWalesAllYearPercent['Other']['2017/18'] / pivotDfWalesAllYearPercent['Total']['2017/18']) * 100
pivotDfWalesAllYearPercent['Female (%) 2018/19'] = (pivotDfWalesAllYearPercent['Female']['2018/19'] / pivotDfWalesAllYearPercent['Total']['2018/19']) * 100
pivotDfWalesAllYearPercent['Male (%) 2018/19'] = (pivotDfWalesAllYearPercent['Male']['2018/19'] / pivotDfWalesAllYearPercent['Total']['2018/19']) * 100
pivotDfWalesAllYearPercent['Other (%) 2018/19'] = (pivotDfWalesAllYearPercent['Other']['2018/19'] / pivotDfWalesAllYearPercent['Total']['2018/19']) * 100

# %%
pivotDfWalesAllYearPercent = pivotDfWalesAllYearPercent.drop(columns=['Female','Male','Other','Total'])

# %%
pivotDfWalesAllYearPercent['Avg. % Change of Female'] = ((pivotDfWalesAllYearPercent['Female (%) 2015/16'] - pivotDfWalesAllYearPercent['Female (%) 2014/15']) +
                                                                (pivotDfWalesAllYearPercent['Female (%) 2016/17'] - pivotDfWalesAllYearPercent['Female (%) 2015/16']) +
                                                                (pivotDfWalesAllYearPercent['Female (%) 2017/18'] - pivotDfWalesAllYearPercent['Female (%) 2016/17']) +
                                                                (pivotDfWalesAllYearPercent['Female (%) 2018/19'] - pivotDfWalesAllYearPercent['Female (%) 2017/18'])) / 4
pivotDfWalesAllYearPercent['Avg. % Change of Male'] = ((pivotDfWalesAllYearPercent['Male (%) 2015/16'] - pivotDfWalesAllYearPercent['Male (%) 2014/15']) +
                                                                (pivotDfWalesAllYearPercent['Male (%) 2016/17'] - pivotDfWalesAllYearPercent['Male (%) 2015/16']) +
                                                                (pivotDfWalesAllYearPercent['Male (%) 2017/18'] - pivotDfWalesAllYearPercent['Male (%) 2016/17']) +
                                                                (pivotDfWalesAllYearPercent['Male (%) 2018/19'] - pivotDfWalesAllYearPercent['Male (%) 2017/18'])) / 4
pivotDfWalesAllYearPercent['Avg. % Change of Other'] = ((pivotDfWalesAllYearPercent['Other (%) 2015/16'] - pivotDfWalesAllYearPercent['Other (%) 2014/15']) +
                                                                (pivotDfWalesAllYearPercent['Other (%) 2016/17'] - pivotDfWalesAllYearPercent['Other (%) 2015/16']) +
                                                                (pivotDfWalesAllYearPercent['Other (%) 2017/18'] - pivotDfWalesAllYearPercent['Other (%) 2016/17']) +
                                                                (pivotDfWalesAllYearPercent['Other (%) 2018/19'] - pivotDfWalesAllYearPercent['Other (%) 2017/18'])) / 4

# %%
pivotDfWalesAllYearAvgPercentChg =  pivotDfWalesAllYearPercent.drop(columns=[
    'Female (%) 2014/15', 'Female (%) 2015/16', 'Female (%) 2016/17', 'Female (%) 2017/18', 'Female (%) 2018/19',
    'Male (%) 2014/15', 'Male (%) 2015/16', 'Male (%) 2016/17', 'Male (%) 2017/18', 'Male (%) 2018/19',
    'Other (%) 2014/15', 'Other (%) 2015/16', 'Other (%) 2016/17', 'Other (%) 2017/18', 'Other (%) 2018/19',
])

# %%
pivotDfWalesAllYearAvgPercentChg[pivotDfWalesAllYearAvgPercentChg['Level of study'] == 'All'].sort_values(by='Avg. % Change of Female', ascending=False)
# Out:
# Sex                                       Subject Area Level of study  \
# Academic Year
# 21                  (5) Agriculture & related subjects            All
# 14                             (3) Biological sciences            All
# 28                               (6) Physical sciences            All
# 0                             (1) Medicine & dentistry            All
# 63                                  (B) Social studies            All
# 77               (D) Business & administrative studies            All
# 56               (A) Architecture, building & planning            All
# 70                                             (C) Law            All
# 112                                      (I) Education            All
# 105                         (H) Creative arts & design            All
# 7                      (2) Subjects allied to medicine            All
# 49                        (9) Engineering & technology            All
# ...

# %% [markdown]
# # Northern Ireland : Finding average change in proportion of students in each sex over 5-year period, categorised by subject area and level of study
# (*not change in exact number of students!)
#
# ## Started by calculate proportion of students in each sex over 5-year period in Northern Ireland

# %%
dfNI = df[(df['First year marker'] == 'All') &
   (df['Mode of study'] == 'All') &
   (df['Country of HE provider'] == 'Northern Ireland') &
    (~df['Subject Area'].str.startswith('Total'))]

# %%
dfNI['Subject Area'].unique()
# Out:
# array(['(1) Medicine & dentistry', '(2) Subjects allied to medicine',
#        '(3) Biological sciences', '(5) Agriculture & related subjects',
#        '(6) Physical sciences', '(7) Mathematical sciences',
#        '(8) Computer science', '(9) Engineering & technology',
#        '(A) Architecture, building & planning', '(B) Social studies',
#        '(C) Law', '(D) Business & administrative studies',
#        '(E) Mass communications & documentation', '(F) Languages',
#        '(G) Historical & philosophical studies',
#        '(H) Creative arts & design', '(I) Education', '(J) Combined'],
#       dtype=object)

# %%
dfNI[dfNI['Subject Area'] == '(E) Mass communications & documentation'].count()
# Out:
# Subject Area              120
# First year marker         120
# Level of study            120
# Mode of study             120
# Country of HE provider    120
# Sex                       120
# Academic Year             120
# Number                    120
# dtype: int64

# %%
dfNI
# Out:
#                     Subject Area First year marker     Level of study  \
# 500     (1) Medicine & dentistry               All                All
# 501     (1) Medicine & dentistry               All                All
# 502     (1) Medicine & dentistry               All                All
# 503     (1) Medicine & dentistry               All                All
# 504     (1) Medicine & dentistry               All                All
# ...                          ...               ...                ...
# 121395              (J) Combined               All  All undergraduate
# 121396              (J) Combined               All  All undergraduate
# 121397              (J) Combined               All  All undergraduate
# 121398              (J) Combined               All  All undergraduate
# 121399              (J) Combined               All  All undergraduate
#
#        Mode of study Country of HE provider     Sex Academic Year  Number
# ...

# %%
pivotDfNI = dfNI.pivot_table(
    'Number', ['Subject Area', 'Level of study', 'Academic Year'], 'Sex').reset_index()

# %%
pivotDfNIAllYear = pivotDfNI.pivot_table(['Female','Male','Other',
                                'Total'], ['Subject Area', 'Level of study'], 'Academic Year').reset_index()

# %%
pivotDfNI['Female (%)'] = (pivotDfNI['Female'] / pivotDfNI['Total']) * 100
pivotDfNI['Male (%)'] = (pivotDfNI['Male'] / pivotDfNI['Total']) * 100
pivotDfNI['Other (%)'] = (pivotDfNI['Other'] / pivotDfNI['Total']) * 100

# %%
pivotDfNI
# Out:
# Sex              Subject Area         Level of study Academic Year  Female  \
# 0    (1) Medicine & dentistry                    All       2014/15    1250
# 1    (1) Medicine & dentistry                    All       2015/16    1270
# 2    (1) Medicine & dentistry                    All       2016/17    1270
# 3    (1) Medicine & dentistry                    All       2017/18    1350
# 4    (1) Medicine & dentistry                    All       2018/19    1340
# ..                        ...                    ...           ...     ...
# 615              (J) Combined  Postgraduate (taught)       2014/15     125
# 616              (J) Combined  Postgraduate (taught)       2015/16     125
# 617              (J) Combined  Postgraduate (taught)       2016/17     130
# 618              (J) Combined  Postgraduate (taught)       2017/18      90
# 619              (J) Combined  Postgraduate (taught)       2018/19      90
#
# Sex  Male  Other  Total  Female (%)   Male (%)  Other (%)
# ...

# %%
pivotDfNI[pivotDfNI['Subject Area'] == '(7) Mathematical sciences']
# Out:
# Sex               Subject Area           Level of study Academic Year  Female  \
# 175  (7) Mathematical sciences                      All       2014/15     245
# 176  (7) Mathematical sciences                      All       2015/16     240
# 177  (7) Mathematical sciences                      All       2016/17     230
# 178  (7) Mathematical sciences                      All       2017/18     245
# 179  (7) Mathematical sciences                      All       2018/19     245
# 180  (7) Mathematical sciences         All postgraduate       2014/15       5
# 181  (7) Mathematical sciences         All postgraduate       2015/16       5
# 182  (7) Mathematical sciences         All postgraduate       2016/17       5
# 183  (7) Mathematical sciences         All postgraduate       2017/18      20
# 184  (7) Mathematical sciences         All postgraduate       2018/19      25
# 185  (7) Mathematical sciences        All undergraduate       2014/15     240
# ...

# %% [markdown]
# ## Then calculate 'average change' in proportion of students in each sex over 5-year period

# %%
pivotDfNIAllYearPercent = pivotDfNIAllYear.copy()

# %%
pivotDfNIAllYearPercent['Female (%) 2014/15'] = (pivotDfNIAllYearPercent['Female']['2014/15'] / pivotDfNIAllYearPercent['Total']['2014/15']) * 100
pivotDfNIAllYearPercent['Male (%) 2014/15'] = (pivotDfNIAllYearPercent['Male']['2014/15'] / pivotDfNIAllYearPercent['Total']['2014/15']) * 100
pivotDfNIAllYearPercent['Other (%) 2014/15'] = (pivotDfNIAllYearPercent['Other']['2014/15'] / pivotDfNIAllYearPercent['Total']['2014/15']) * 100
pivotDfNIAllYearPercent['Female (%) 2015/16'] = (pivotDfNIAllYearPercent['Female']['2015/16'] / pivotDfNIAllYearPercent['Total']['2015/16']) * 100
pivotDfNIAllYearPercent['Male (%) 2015/16'] = (pivotDfNIAllYearPercent['Male']['2015/16'] / pivotDfNIAllYearPercent['Total']['2015/16']) * 100
pivotDfNIAllYearPercent['Other (%) 2015/16'] = (pivotDfNIAllYearPercent['Other']['2015/16'] / pivotDfNIAllYearPercent['Total']['2015/16']) * 100
pivotDfNIAllYearPercent['Female (%) 2016/17'] = (pivotDfNIAllYearPercent['Female']['2016/17'] / pivotDfNIAllYearPercent['Total']['2016/17']) * 100
pivotDfNIAllYearPercent['Male (%) 2016/17'] = (pivotDfNIAllYearPercent['Male']['2016/17'] / pivotDfNIAllYearPercent['Total']['2016/17']) * 100
pivotDfNIAllYearPercent['Other (%) 2016/17'] = (pivotDfNIAllYearPercent['Other']['2016/17'] / pivotDfNIAllYearPercent['Total']['2016/17']) * 100
pivotDfNIAllYearPercent['Female (%) 2017/18'] = (pivotDfNIAllYearPercent['Female']['2017/18'] / pivotDfNIAllYearPercent['Total']['2017/18']) * 100
pivotDfNIAllYearPercent['Male (%) 2017/18'] = (pivotDfNIAllYearPercent['Male']['2017/18'] / pivotDfNIAllYearPercent['Total']['2017/18']) * 100
pivotDfNIAllYearPercent['Other (%) 2017/18'] = (pivotDfNIAllYearPercent['Other']['2017/18'] / pivotDfNIAllYearPercent['Total']['2017/18']) * 100
pivotDfNIAllYearPercent['Female (%) 2018/19'] = (pivotDfNIAllYearPercent['Female']['2018/19'] / pivotDfNIAllYearPercent['Total']['2018/19']) * 100
pivotDfNIAllYearPercent['Male (%) 2018/19'] = (pivotDfNIAllYearPercent['Male']['2018/19'] / pivotDfNIAllYearPercent['Total']['2018/19']) * 100
pivotDfNIAllYearPercent['Other (%) 2018/19'] = (pivotDfNIAllYearPercent['Other']['2018/19'] / pivotDfNIAllYearPercent['Total']['2018/19']) * 100

# %%
pivotDfNIAllYearPercent = pivotDfNIAllYearPercent.drop(columns=['Female','Male','Other','Total'])

# %%
pivotDfNIAllYearPercent['Avg. % Change of Female'] = ((pivotDfNIAllYearPercent['Female (%) 2015/16'] - pivotDfNIAllYearPercent['Female (%) 2014/15']) +
                                                                (pivotDfNIAllYearPercent['Female (%) 2016/17'] - pivotDfNIAllYearPercent['Female (%) 2015/16']) +
                                                                (pivotDfNIAllYearPercent['Female (%) 2017/18'] - pivotDfNIAllYearPercent['Female (%) 2016/17']) +
                                                                (pivotDfNIAllYearPercent['Female (%) 2018/19'] - pivotDfNIAllYearPercent['Female (%) 2017/18'])) / 4
pivotDfNIAllYearPercent['Avg. % Change of Male'] = ((pivotDfNIAllYearPercent['Male (%) 2015/16'] - pivotDfNIAllYearPercent['Male (%) 2014/15']) +
                                                                (pivotDfNIAllYearPercent['Male (%) 2016/17'] - pivotDfNIAllYearPercent['Male (%) 2015/16']) +
                                                                (pivotDfNIAllYearPercent['Male (%) 2017/18'] - pivotDfNIAllYearPercent['Male (%) 2016/17']) +
                                                                (pivotDfNIAllYearPercent['Male (%) 2018/19'] - pivotDfNIAllYearPercent['Male (%) 2017/18'])) / 4
pivotDfNIAllYearPercent['Avg. % Change of Other'] = ((pivotDfNIAllYearPercent['Other (%) 2015/16'] - pivotDfNIAllYearPercent['Other (%) 2014/15']) +
                                                                (pivotDfNIAllYearPercent['Other (%) 2016/17'] - pivotDfNIAllYearPercent['Other (%) 2015/16']) +
                                                                (pivotDfNIAllYearPercent['Other (%) 2017/18'] - pivotDfNIAllYearPercent['Other (%) 2016/17']) +
                                                                (pivotDfNIAllYearPercent['Other (%) 2018/19'] - pivotDfNIAllYearPercent['Other (%) 2017/18'])) / 4

# %%
pivotDfNIAllYearAvgPercentChg =  pivotDfNIAllYearPercent.drop(columns=[
    'Female (%) 2014/15', 'Female (%) 2015/16', 'Female (%) 2016/17', 'Female (%) 2017/18', 'Female (%) 2018/19',
    'Male (%) 2014/15', 'Male (%) 2015/16', 'Male (%) 2016/17', 'Male (%) 2017/18', 'Male (%) 2018/19',
    'Other (%) 2014/15', 'Other (%) 2015/16', 'Other (%) 2016/17', 'Other (%) 2017/18', 'Other (%) 2018/19',
])

# %%
pivotDfNIAllYearAvgPercentChg[pivotDfNIAllYearAvgPercentChg['Level of study'] == 'All'].sort_values(by='Avg. % Change of Female', ascending=False)
# Out:
# Sex                                       Subject Area Level of study  \
# Academic Year
# 118                                       (J) Combined            All
# 49                        (9) Engineering & technology            All
# 70                                             (C) Law            All
# 104                         (H) Creative arts & design            All
# 21                  (5) Agriculture & related subjects            All
# 97              (G) Historical & philosophical studies            All
# 0                             (1) Medicine & dentistry            All
# 84             (E) Mass communications & documentation            All
# 28                               (6) Physical sciences            All
# 90                                       (F) Languages            All
# 77               (D) Business & administrative studies            All
# 7                      (2) Subjects allied to medicine            All
# ...

# %% [markdown]
# # Scotland : Finding average change in proportion of students in each sex over 5-year period, categorised by subject area and level of study
# (*not change in exact number of students!)
#
# ## Started by calculate proportion of students in each sex over 5-year period in Scotland

# %%
dfScotland = df[(df['First year marker'] == 'All') &
   (df['Mode of study'] == 'All') &
   (df['Country of HE provider'] == 'Scotland') &
    (~df['Subject Area'].str.startswith('Total'))]

# %%
dfScotland
# Out:
#                     Subject Area First year marker     Level of study  \
# 520     (1) Medicine & dentistry               All                All
# 521     (1) Medicine & dentistry               All                All
# 522     (1) Medicine & dentistry               All                All
# 523     (1) Medicine & dentistry               All                All
# 524     (1) Medicine & dentistry               All                All
# ...                          ...               ...                ...
# 121415              (J) Combined               All  All undergraduate
# 121416              (J) Combined               All  All undergraduate
# 121417              (J) Combined               All  All undergraduate
# 121418              (J) Combined               All  All undergraduate
# 121419              (J) Combined               All  All undergraduate
#
#        Mode of study Country of HE provider     Sex Academic Year  Number
# ...

# %%
pivotDfScotland = dfScotland.pivot_table(
    'Number', ['Subject Area', 'Level of study', 'Academic Year'], 'Sex').reset_index()

# %%
pivotDfScotlandAllYear = pivotDfScotland.pivot_table(['Female','Male','Other',
                                'Total'], ['Subject Area', 'Level of study'], 'Academic Year').reset_index()

# %%
pivotDfScotland['Female (%)'] = (pivotDfScotland['Female'] / pivotDfScotland['Total']) * 100
pivotDfScotland['Male (%)'] = (pivotDfScotland['Male'] / pivotDfScotland['Total']) * 100
pivotDfScotland['Other (%)'] = (pivotDfScotland['Other'] / pivotDfScotland['Total']) * 100

# %%
pivotDfScotland
# Out:
# Sex              Subject Area         Level of study Academic Year  Female  \
# 0    (1) Medicine & dentistry                    All       2014/15    4440
# 1    (1) Medicine & dentistry                    All       2015/16    4500
# 2    (1) Medicine & dentistry                    All       2016/17    4570
# 3    (1) Medicine & dentistry                    All       2017/18    4635
# 4    (1) Medicine & dentistry                    All       2018/19    4770
# ..                        ...                    ...           ...     ...
# 650              (J) Combined  Postgraduate (taught)       2014/15     180
# 651              (J) Combined  Postgraduate (taught)       2015/16     115
# 652              (J) Combined  Postgraduate (taught)       2016/17      55
# 653              (J) Combined  Postgraduate (taught)       2017/18      70
# 654              (J) Combined  Postgraduate (taught)       2018/19     110
#
# Sex  Male  Other  Total  Female (%)   Male (%)  Other (%)
# ...

# %% [markdown]
# ## Then calculate 'average change' in proportion of students in each sex over 5-year period

# %%
pivotDfScotlandAllYearPercent = pivotDfScotlandAllYear.copy()

# %%
pivotDfScotlandAllYearPercent['Female (%) 2014/15'] = (pivotDfScotlandAllYearPercent['Female']['2014/15'] / pivotDfScotlandAllYearPercent['Total']['2014/15']) * 100
pivotDfScotlandAllYearPercent['Male (%) 2014/15'] = (pivotDfScotlandAllYearPercent['Male']['2014/15'] / pivotDfScotlandAllYearPercent['Total']['2014/15']) * 100
pivotDfScotlandAllYearPercent['Other (%) 2014/15'] = (pivotDfScotlandAllYearPercent['Other']['2014/15'] / pivotDfScotlandAllYearPercent['Total']['2014/15']) * 100
pivotDfScotlandAllYearPercent['Female (%) 2015/16'] = (pivotDfScotlandAllYearPercent['Female']['2015/16'] / pivotDfScotlandAllYearPercent['Total']['2015/16']) * 100
pivotDfScotlandAllYearPercent['Male (%) 2015/16'] = (pivotDfScotlandAllYearPercent['Male']['2015/16'] / pivotDfScotlandAllYearPercent['Total']['2015/16']) * 100
pivotDfScotlandAllYearPercent['Other (%) 2015/16'] = (pivotDfScotlandAllYearPercent['Other']['2015/16'] / pivotDfScotlandAllYearPercent['Total']['2015/16']) * 100
pivotDfScotlandAllYearPercent['Female (%) 2016/17'] = (pivotDfScotlandAllYearPercent['Female']['2016/17'] / pivotDfScotlandAllYearPercent['Total']['2016/17']) * 100
pivotDfScotlandAllYearPercent['Male (%) 2016/17'] = (pivotDfScotlandAllYearPercent['Male']['2016/17'] / pivotDfScotlandAllYearPercent['Total']['2016/17']) * 100
pivotDfScotlandAllYearPercent['Other (%) 2016/17'] = (pivotDfScotlandAllYearPercent['Other']['2016/17'] / pivotDfScotlandAllYearPercent['Total']['2016/17']) * 100
pivotDfScotlandAllYearPercent['Female (%) 2017/18'] = (pivotDfScotlandAllYearPercent['Female']['2017/18'] / pivotDfScotlandAllYearPercent['Total']['2017/18']) * 100
pivotDfScotlandAllYearPercent['Male (%) 2017/18'] = (pivotDfScotlandAllYearPercent['Male']['2017/18'] / pivotDfScotlandAllYearPercent['Total']['2017/18']) * 100
pivotDfScotlandAllYearPercent['Other (%) 2017/18'] = (pivotDfScotlandAllYearPercent['Other']['2017/18'] / pivotDfScotlandAllYearPercent['Total']['2017/18']) * 100
pivotDfScotlandAllYearPercent['Female (%) 2018/19'] = (pivotDfScotlandAllYearPercent['Female']['2018/19'] / pivotDfScotlandAllYearPercent['Total']['2018/19']) * 100
pivotDfScotlandAllYearPercent['Male (%) 2018/19'] = (pivotDfScotlandAllYearPercent['Male']['2018/19'] / pivotDfScotlandAllYearPercent['Total']['2018/19']) * 100
pivotDfScotlandAllYearPercent['Other (%) 2018/19'] = (pivotDfScotlandAllYearPercent['Other']['2018/19'] / pivotDfScotlandAllYearPercent['Total']['2018/19']) * 100

# %%
pivotDfScotlandAllYearPercent = pivotDfScotlandAllYearPercent.drop(columns=['Female','Male','Other','Total'])

# %%
pivotDfScotlandAllYearPercent['Avg. % Change of Female'] = ((pivotDfScotlandAllYearPercent['Female (%) 2015/16'] - pivotDfScotlandAllYearPercent['Female (%) 2014/15']) +
                                                                (pivotDfScotlandAllYearPercent['Female (%) 2016/17'] - pivotDfScotlandAllYearPercent['Female (%) 2015/16']) +
                                                                (pivotDfScotlandAllYearPercent['Female (%) 2017/18'] - pivotDfScotlandAllYearPercent['Female (%) 2016/17']) +
                                                                (pivotDfScotlandAllYearPercent['Female (%) 2018/19'] - pivotDfScotlandAllYearPercent['Female (%) 2017/18'])) / 4
pivotDfScotlandAllYearPercent['Avg. % Change of Male'] = ((pivotDfScotlandAllYearPercent['Male (%) 2015/16'] - pivotDfScotlandAllYearPercent['Male (%) 2014/15']) +
                                                                (pivotDfScotlandAllYearPercent['Male (%) 2016/17'] - pivotDfScotlandAllYearPercent['Male (%) 2015/16']) +
                                                                (pivotDfScotlandAllYearPercent['Male (%) 2017/18'] - pivotDfScotlandAllYearPercent['Male (%) 2016/17']) +
                                                                (pivotDfScotlandAllYearPercent['Male (%) 2018/19'] - pivotDfScotlandAllYearPercent['Male (%) 2017/18'])) / 4
pivotDfScotlandAllYearPercent['Avg. % Change of Other'] = ((pivotDfScotlandAllYearPercent['Other (%) 2015/16'] - pivotDfScotlandAllYearPercent['Other (%) 2014/15']) +
                                                                (pivotDfScotlandAllYearPercent['Other (%) 2016/17'] - pivotDfScotlandAllYearPercent['Other (%) 2015/16']) +
                                                                (pivotDfScotlandAllYearPercent['Other (%) 2017/18'] - pivotDfScotlandAllYearPercent['Other (%) 2016/17']) +
                                                                (pivotDfScotlandAllYearPercent['Other (%) 2018/19'] - pivotDfScotlandAllYearPercent['Other (%) 2017/18'])) / 4

# %%
pivotDfScotlandAllYearAvgPercentChg =  pivotDfScotlandAllYearPercent.drop(columns=[
    'Female (%) 2014/15', 'Female (%) 2015/16', 'Female (%) 2016/17', 'Female (%) 2017/18', 'Female (%) 2018/19',
    'Male (%) 2014/15', 'Male (%) 2015/16', 'Male (%) 2016/17', 'Male (%) 2017/18', 'Male (%) 2018/19',
    'Other (%) 2014/15', 'Other (%) 2015/16', 'Other (%) 2016/17', 'Other (%) 2017/18', 'Other (%) 2018/19',
])

# %%
pivotDfScotlandAllYearAvgPercentChg[pivotDfScotlandAllYearAvgPercentChg['Level of study'] == 'All'].sort_values(by='Avg. % Change of Female', ascending=False)
# Out:
# Sex                                       Subject Area Level of study  \
# Academic Year
# 21                              (4) Veterinary science            All
# 0                             (1) Medicine & dentistry            All
# 76                                             (C) Law            All
# 34                               (6) Physical sciences            All
# 27                  (5) Agriculture & related subjects            All
# 90             (E) Mass communications & documentation            All
# 69                                  (B) Social studies            All
# 55                        (9) Engineering & technology            All
# 104             (G) Historical & philosophical studies            All
# 48                                (8) Computer science            All
# 125                                       (J) Combined            All
# 14                             (3) Biological sciences            All
# ...
