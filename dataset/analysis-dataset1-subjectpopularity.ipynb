# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('dataset-1.csv')

# %%
df.head(10)
# Out:
#                Subject Area First year marker Level of study Mode of study  \
# 0  (1) Medicine & dentistry               All            All     Full-time
# 1  (1) Medicine & dentistry               All            All     Full-time
# 2  (1) Medicine & dentistry               All            All     Full-time
# 3  (1) Medicine & dentistry               All            All     Full-time
# 4  (1) Medicine & dentistry               All            All     Full-time
# 5  (1) Medicine & dentistry               All            All     Full-time
# 6  (1) Medicine & dentistry               All            All     Full-time
# 7  (1) Medicine & dentistry               All            All     Full-time
# 8  (1) Medicine & dentistry               All            All     Full-time
# 9  (1) Medicine & dentistry               All            All     Full-time
#
#   Country of HE provider     Sex Academic Year  Number
# 0                England  Female       2014/15   24835
# ...

# %% [markdown]
# # View table structure and values for each column

# %%
df['Subject Area'].unique()
# Out:
# array(['(1) Medicine & dentistry', '(2) Subjects allied to medicine',
#        '(3) Biological sciences', '(4) Veterinary science',
#        '(5) Agriculture & related subjects', '(6) Physical sciences',
#        '(7) Mathematical sciences', '(8) Computer science',
#        '(9) Engineering & technology',
#        '(A) Architecture, building & planning',
#        'Total - Science subject areas', '(B) Social studies', '(C) Law',
#        '(D) Business & administrative studies',
#        '(E) Mass communications & documentation', '(F) Languages',
#        '(G) Historical & philosophical studies',
#        '(H) Creative arts & design', '(I) Education', '(J) Combined',
#        'Total - Non-science subject areas', 'Total'], dtype=object)

# %%
df['Level of study'].unique()
# Out:
# array(['All', 'Postgraduate (research)', 'Postgraduate (taught)',
#        'All postgraduate', 'First degree', 'Other undergraduate',
#        'All undergraduate'], dtype=object)

# %%
df['First year marker'].unique()
# Out:
# array(['All', 'First year', 'Other years'], dtype=object)

# %%
df['Level of study'].unique()
# Out:
# array(['All', 'Postgraduate (research)', 'Postgraduate (taught)',
#        'All postgraduate', 'First degree', 'Other undergraduate',
#        'All undergraduate'], dtype=object)

# %%
df['Mode of study'].unique()
# Out:
# array(['Full-time', 'Part-time', 'All'], dtype=object)

# %%
df['Country of HE provider'].unique()
# Out:
# array(['England', 'Northern Ireland', 'Scotland', 'Wales', 'All'],
#       dtype=object)

# %%
df['Sex'].unique()
# Out:
# array(['Female', 'Male', 'Other', 'Total'], dtype=object)

# %%
df['Academic Year'].unique()
# Out:
# array(['2014/15', '2015/16', '2016/17', '2017/18', '2018/19'],
#       dtype=object)

# %% [markdown]
# # Compare each subject area by level of study

# %%
df[(df['Subject Area'] == '(1) Medicine & dentistry') &
   (df['First year marker'] == 'All') &
   (df['Mode of study'] == 'All') &
   (df['Country of HE provider'] == 'All') &
   (df['Sex'] == 'Total') &
   (df['Academic Year'] == '2014/15') &
   ((df['Level of study'] == 'All postgraduate') | (df['Level of study'] == 'All undergraduate'))]
# Out:
#                   Subject Area First year marker     Level of study  \
# 3423  (1) Medicine & dentistry               All   All postgraduate
# 5983  (1) Medicine & dentistry               All  All undergraduate
#
#      Mode of study Country of HE provider    Sex Academic Year  Number
# 3423           All                    All  Total       2014/15   20395
# 5983           All                    All  Total       2014/15   45605

# %%
df[(df['First year marker'] == 'All') &
   (df['Mode of study'] == 'All') &
   (df['Country of HE provider'] == 'All') &
   (df['Sex'] == 'Total') &
   (df['Academic Year'] == '2014/15') &
   ((df['Level of study'] == 'All postgraduate') | (df['Level of study'] == 'All undergraduate'))]
# Out:
#                                    Subject Area First year marker  \
# 3423                   (1) Medicine & dentistry               All
# 5983                   (1) Medicine & dentistry               All
# 9583            (2) Subjects allied to medicine               All
# 12283           (2) Subjects allied to medicine               All
# 15883                   (3) Biological sciences               All
# 18583                   (3) Biological sciences               All
# 20743                    (4) Veterinary science               All
# 21983                    (4) Veterinary science               All
# 25583        (5) Agriculture & related subjects               All
# 28243        (5) Agriculture & related subjects               All
# 31843                     (6) Physical sciences               All
# 34543                     (6) Physical sciences               All
# 38123                 (7) Mathematical sciences               All
# ...

# %% [markdown]
# ### Postgraduate in UK

# %%
df[(df['First year marker'] == 'All') &
   (df['Mode of study'] == 'All') &
   (df['Country of HE provider'] == 'All') &
   (df['Sex'] == 'Total') &
   (df['Academic Year'] == '2014/15') &
   ((df['Level of study'] == 'All postgraduate'))]
# Out:
#                                    Subject Area First year marker  \
# 3423                   (1) Medicine & dentistry               All
# 9583            (2) Subjects allied to medicine               All
# 15883                   (3) Biological sciences               All
# 20743                    (4) Veterinary science               All
# 25583        (5) Agriculture & related subjects               All
# 31843                     (6) Physical sciences               All
# 38123                 (7) Mathematical sciences               All
# 44403                      (8) Computer science               All
# 50683              (9) Engineering & technology               All
# 56983     (A) Architecture, building & planning               All
# 62503             Total - Science subject areas               All
# 69523                        (B) Social studies               All
# 75823                                   (C) Law               All
# ...

# %%
dfPostGrad = df[(df['First year marker'] == 'All') &
   (df['Mode of study'] == 'All') &
   (df['Country of HE provider'] == 'All') &
   (df['Sex'] == 'Total') &
   ((df['Level of study'] == 'All postgraduate')) &
    (~df['Subject Area'].str.startswith('Total'))]

# %%
dfPostGrad[['Subject Area', 'Academic Year', 'Number']]
# Out:
#                     Subject Area Academic Year  Number
# 3423    (1) Medicine & dentistry       2014/15   20395
# 3427    (1) Medicine & dentistry       2015/16   20310
# 3431    (1) Medicine & dentistry       2016/17   19770
# 3435    (1) Medicine & dentistry       2017/18   19915
# 3439    (1) Medicine & dentistry       2018/19   20120
# ...                          ...           ...     ...
# 118963              (J) Combined       2014/15    1920
# 118967              (J) Combined       2015/16    1795
# 118971              (J) Combined       2016/17    1440
# 118975              (J) Combined       2017/18    1355
# 118979              (J) Combined       2018/19    1305
#
# [95 rows x 3 columns]

# %%
pivotDfGrad = dfPostGrad.pivot_table('Number', ['Subject Area'], 'Academic Year')

# %%
pivotDfGrad
# Out:
# Academic Year                            2014/15  2015/16  2016/17  2017/18  \
# Subject Area
# (1) Medicine & dentistry                   20395    20310    19770    19915
# (2) Subjects allied to medicine            62610    67705    73145    73795
# (3) Biological sciences                    34600    35645    41160    44740
# (4) Veterinary science                       815     1520     1680     2145
# (5) Agriculture & related subjects          4075     3430     3565     3650
# (6) Physical sciences                      19870    19565    20120    20910
# (7) Mathematical sciences                   6270     6380     6745     6955
# (8) Computer science                       16740    16700    17500    19225
# (9) Engineering & technology               39760    38755    38295    37630
# (A) Architecture, building & planning      14945    15370    16465    17015
# (B) Social studies                         48400    48705    51345    52420
# ...

# %%
pivotDfGrad.sort_values(by='2018/19', ascending=False)
# Out:
# Academic Year                            2014/15  2015/16  2016/17  2017/18  \
# Subject Area
# (D) Business & administrative studies     103210    97790    98095   102930
# (2) Subjects allied to medicine            62610    67705    73145    73795
# (I) Education                              81425    75535    73395    71665
# (B) Social studies                         48400    48705    51345    52420
# (3) Biological sciences                    34600    35645    41160    44740
# (9) Engineering & technology               39760    38755    38295    37630
# (H) Creative arts & design                 21605    21920    24925    26460
# (8) Computer science                       16740    16700    17500    19225
# (6) Physical sciences                      19870    19565    20120    20910
# (C) Law                                    19445    19545    20135    20375
# (1) Medicine & dentistry                   20395    20310    19770    19915
# ...

# %%
pivotDfGrad.sort_values(by='2014/15', ascending=False)
# Out:
# Academic Year                            2014/15  2015/16  2016/17  2017/18  \
# Subject Area
# (D) Business & administrative studies     103210    97790    98095   102930
# (I) Education                              81425    75535    73395    71665
# (2) Subjects allied to medicine            62610    67705    73145    73795
# (B) Social studies                         48400    48705    51345    52420
# (9) Engineering & technology               39760    38755    38295    37630
# (3) Biological sciences                    34600    35645    41160    44740
# (H) Creative arts & design                 21605    21920    24925    26460
# (1) Medicine & dentistry                   20395    20310    19770    19915
# (6) Physical sciences                      19870    19565    20120    20910
# (C) Law                                    19445    19545    20135    20375
# (8) Computer science                       16740    16700    17500    19225
# ...

# %%
pivotDfGrad.sort_values(by='2015/16', ascending=False)
# Out:
# Academic Year                            2014/15  2015/16  2016/17  2017/18  \
# Subject Area
# (D) Business & administrative studies     103210    97790    98095   102930
# (I) Education                              81425    75535    73395    71665
# (2) Subjects allied to medicine            62610    67705    73145    73795
# (B) Social studies                         48400    48705    51345    52420
# (9) Engineering & technology               39760    38755    38295    37630
# (3) Biological sciences                    34600    35645    41160    44740
# (H) Creative arts & design                 21605    21920    24925    26460
# (1) Medicine & dentistry                   20395    20310    19770    19915
# (6) Physical sciences                      19870    19565    20120    20910
# (C) Law                                    19445    19545    20135    20375
# (8) Computer science                       16740    16700    17500    19225
# ...

# %%
pivotDfGrad.sort_values(by='2016/17', ascending=False)
# Out:
# Academic Year                            2014/15  2015/16  2016/17  2017/18  \
# Subject Area
# (D) Business & administrative studies     103210    97790    98095   102930
# (I) Education                              81425    75535    73395    71665
# (2) Subjects allied to medicine            62610    67705    73145    73795
# (B) Social studies                         48400    48705    51345    52420
# (3) Biological sciences                    34600    35645    41160    44740
# (9) Engineering & technology               39760    38755    38295    37630
# (H) Creative arts & design                 21605    21920    24925    26460
# (C) Law                                    19445    19545    20135    20375
# (6) Physical sciences                      19870    19565    20120    20910
# (1) Medicine & dentistry                   20395    20310    19770    19915
# (8) Computer science                       16740    16700    17500    19225
# ...

# %%
pivotDfGrad.sort_values(by='2017/18', ascending=False)
# Out:
# Academic Year                            2014/15  2015/16  2016/17  2017/18  \
# Subject Area
# (D) Business & administrative studies     103210    97790    98095   102930
# (2) Subjects allied to medicine            62610    67705    73145    73795
# (I) Education                              81425    75535    73395    71665
# (B) Social studies                         48400    48705    51345    52420
# (3) Biological sciences                    34600    35645    41160    44740
# (9) Engineering & technology               39760    38755    38295    37630
# (H) Creative arts & design                 21605    21920    24925    26460
# (6) Physical sciences                      19870    19565    20120    20910
# (C) Law                                    19445    19545    20135    20375
# (1) Medicine & dentistry                   20395    20310    19770    19915
# (8) Computer science                       16740    16700    17500    19225
# ...

# %%
pivotDfGrad['%Change 14/15 to 15/16'] = ((pivotDfGrad['2015/16'] - pivotDfGrad['2014/15'])/pivotDfGrad['2014/15']) * 100
pivotDfGrad['%Change 15/16 to 16/17'] = ((pivotDfGrad['2016/17'] - pivotDfGrad['2015/16'])/pivotDfGrad['2015/16']) * 100
pivotDfGrad['%Change 16/17 to 17/18'] = ((pivotDfGrad['2017/18'] - pivotDfGrad['2016/17'])/pivotDfGrad['2016/17']) * 100
pivotDfGrad['%Change 17/18 to 18/19'] = ((pivotDfGrad['2018/19'] - pivotDfGrad['2017/18'])/pivotDfGrad['2017/18']) * 100
pivotDfGrad['%Change 14/15 to 18/19'] = ((pivotDfGrad['2018/19'] - pivotDfGrad['2014/15'])/pivotDfGrad['2014/15']) * 100
pivotDfGrad['Avg. %Change 14/15 to 18/19'] = (pivotDfGrad['%Change 14/15 to 15/16'] + pivotDfGrad['%Change 15/16 to 16/17'] + pivotDfGrad['%Change 16/17 to 17/18'] + pivotDfGrad['%Change 17/18 to 18/19']) / 4

# %%
pivotDfGrad['Median of %Change 14/15 to 18/19'] = pivotDfGrad[['%Change 14/15 to 15/16', '%Change 15/16 to 16/17', '%Change 16/17 to 17/18', '%Change 17/18 to 18/19']].median(1)

# %%
pivotDfGrad
# Out:
# Academic Year                            2014/15  2015/16  2016/17  2017/18  \
# Subject Area
# (1) Medicine & dentistry                   20395    20310    19770    19915
# (2) Subjects allied to medicine            62610    67705    73145    73795
# (3) Biological sciences                    34600    35645    41160    44740
# (4) Veterinary science                       815     1520     1680     2145
# (5) Agriculture & related subjects          4075     3430     3565     3650
# (6) Physical sciences                      19870    19565    20120    20910
# (7) Mathematical sciences                   6270     6380     6745     6955
# (8) Computer science                       16740    16700    17500    19225
# (9) Engineering & technology               39760    38755    38295    37630
# (A) Architecture, building & planning      14945    15370    16465    17015
# (B) Social studies                         48400    48705    51345    52420
# ...

# %% [markdown]
# ##### We will see the trend how the numbers has changed, some fields are become less popular and otherwise are become more popular
# ##### Top 5 subjects with highest number of students are Business, Subject allied to medicine, Education, Social Studies, and Biological Sciences
# ##### Top 5 subjects with highest increase in number of students (4-year-period / percentage) are Veterinary Science, Biological Science, Computer Science, Creative Arts & Design, Subjects allied to Medicine
# ##### Top 5 subjects with highest decrease "or" lowest increase in number of students (4-year-period / percentage) are Combined, Education, Agriculture, Engineering & technology, Medicine & Dentistry
# ##### Top 5 subjects with highest average increase rate in number of students per year are Veterinary Science, Biological Science, Computer Science, Creative Arts & Design, Subjects allied to Medicine
# ##### Top 5 subjects with highest average decrease rate "or" lowest average increase rate in number of students per year are Combined, Education, Agriculture, Engineering & technology, Medicine & Dentistry
# ##### Top 5 subjects with highest median increase rate in number of students per year are Veterinary Science, Computer Science, Biological Science, Mass Communication & Documentary, Subjects allied to Medicine
# ##### Top 5 subjects with highest median decrease rate "or" lowest median increase rate in number of students per year are Combined, Education, Engineering & technology, Historical & Philosophical, Medicine & dentistry

# %% [markdown]
# ### Undergraduate in UK

# %%
dfUnderGrad = df[(df['First year marker'] == 'All') &
   (df['Mode of study'] == 'All') &
   (df['Country of HE provider'] == 'All') &
   (df['Sex'] == 'Total') &
   ((df['Level of study'] == 'All undergraduate')) &
    (~df['Subject Area'].str.startswith('Total'))]

# %%
pivotDfUnderGrad = dfUnderGrad.pivot_table('Number', ['Subject Area'], 'Academic Year')

# %%
pivotDfUnderGrad.sort_values(by='2014/15', ascending=False)
# Out:
# Academic Year                            2014/15  2015/16  2016/17  2017/18  \
# Subject Area
# (D) Business & administrative studies     223590   228450   235330   240040
# (2) Subjects allied to medicine           212735   217215   217625   214265
# (3) Biological sciences                   176760   181725   185240   189230
# (B) Social studies                        159600   165170   170365   176940
# (H) Creative arts & design                145330   147930   150775   151955
# (9) Engineering & technology              121560   124400   126860   127345
# (F) Languages                              95965    93670    91105    87360
# (I) Education                              82970    80630    77660    73780
# (8) Computer science                       76490    79495    83645    88025
# (6) Physical sciences                      73890    75305    75050    74805
# (G) Historical & philosophical studies     69985    69370    68400    66865
# ...

# %%
pivotDfUnderGrad.sort_values(by='2015/16', ascending=False)
# Out:
# Academic Year                            2014/15  2015/16  2016/17  2017/18  \
# Subject Area
# (D) Business & administrative studies     223590   228450   235330   240040
# (2) Subjects allied to medicine           212735   217215   217625   214265
# (3) Biological sciences                   176760   181725   185240   189230
# (B) Social studies                        159600   165170   170365   176940
# (H) Creative arts & design                145330   147930   150775   151955
# (9) Engineering & technology              121560   124400   126860   127345
# (F) Languages                              95965    93670    91105    87360
# (I) Education                              82970    80630    77660    73780
# (8) Computer science                       76490    79495    83645    88025
# (6) Physical sciences                      73890    75305    75050    74805
# (G) Historical & philosophical studies     69985    69370    68400    66865
# ...

# %%
pivotDfUnderGrad.sort_values(by='2016/17', ascending=False)
# Out:
# Academic Year                            2014/15  2015/16  2016/17  2017/18  \
# Subject Area
# (D) Business & administrative studies     223590   228450   235330   240040
# (2) Subjects allied to medicine           212735   217215   217625   214265
# (3) Biological sciences                   176760   181725   185240   189230
# (B) Social studies                        159600   165170   170365   176940
# (H) Creative arts & design                145330   147930   150775   151955
# (9) Engineering & technology              121560   124400   126860   127345
# (F) Languages                              95965    93670    91105    87360
# (8) Computer science                       76490    79495    83645    88025
# (I) Education                              82970    80630    77660    73780
# (6) Physical sciences                      73890    75305    75050    74805
# (C) Law                                    68160    69015    69595    71795
# ...

# %%
pivotDfUnderGrad.sort_values(by='2017/18', ascending=False)
# Out:
# Academic Year                            2014/15  2015/16  2016/17  2017/18  \
# Subject Area
# (D) Business & administrative studies     223590   228450   235330   240040
# (2) Subjects allied to medicine           212735   217215   217625   214265
# (3) Biological sciences                   176760   181725   185240   189230
# (B) Social studies                        159600   165170   170365   176940
# (H) Creative arts & design                145330   147930   150775   151955
# (9) Engineering & technology              121560   124400   126860   127345
# (8) Computer science                       76490    79495    83645    88025
# (F) Languages                              95965    93670    91105    87360
# (6) Physical sciences                      73890    75305    75050    74805
# (I) Education                              82970    80630    77660    73780
# (C) Law                                    68160    69015    69595    71795
# ...

# %%
pivotDfUnderGrad.sort_values(by='2018/19', ascending=False)
# Out:
# Academic Year                            2014/15  2015/16  2016/17  2017/18  \
# Subject Area
# (D) Business & administrative studies     223590   228450   235330   240040
# (2) Subjects allied to medicine           212735   217215   217625   214265
# (3) Biological sciences                   176760   181725   185240   189230
# (B) Social studies                        159600   165170   170365   176940
# (H) Creative arts & design                145330   147930   150775   151955
# (9) Engineering & technology              121560   124400   126860   127345
# (8) Computer science                       76490    79495    83645    88025
# (F) Languages                              95965    93670    91105    87360
# (C) Law                                    68160    69015    69595    71795
# (6) Physical sciences                      73890    75305    75050    74805
# (I) Education                              82970    80630    77660    73780
# ...

# %%
pivotDfUnderGrad['%Change 14/15 to 15/16'] = ((pivotDfUnderGrad['2015/16'] - pivotDfUnderGrad['2014/15'])/pivotDfUnderGrad['2014/15']) * 100
pivotDfUnderGrad['%Change 15/16 to 16/17'] = ((pivotDfUnderGrad['2016/17'] - pivotDfUnderGrad['2015/16'])/pivotDfUnderGrad['2015/16']) * 100
pivotDfUnderGrad['%Change 16/17 to 17/18'] = ((pivotDfUnderGrad['2017/18'] - pivotDfUnderGrad['2016/17'])/pivotDfUnderGrad['2016/17']) * 100
pivotDfUnderGrad['%Change 17/18 to 18/19'] = ((pivotDfUnderGrad['2018/19'] - pivotDfUnderGrad['2017/18'])/pivotDfUnderGrad['2017/18']) * 100
pivotDfUnderGrad['%Change 14/15 to 18/19'] = ((pivotDfUnderGrad['2018/19'] - pivotDfUnderGrad['2014/15'])/pivotDfUnderGrad['2014/15']) * 100
pivotDfUnderGrad['Avg. %Change 14/15 to 18/19'] = (pivotDfUnderGrad['%Change 14/15 to 15/16'] + pivotDfUnderGrad['%Change 15/16 to 16/17'] + pivotDfUnderGrad['%Change 16/17 to 17/18'] + pivotDfUnderGrad['%Change 17/18 to 18/19']) / 4

# %%
pivotDfUnderGrad['Median of %Change 14/15 to 18/19'] = pivotDfUnderGrad[['%Change 14/15 to 15/16', '%Change 15/16 to 16/17', '%Change 16/17 to 17/18', '%Change 17/18 to 18/19']].median(1)

# %%
pivotDfUnderGrad
# Out:
# Academic Year                            2014/15  2015/16  2016/17  2017/18  \
# Subject Area
# (1) Medicine & dentistry                   45605    45235    45340    45965
# (2) Subjects allied to medicine           212735   217215   217625   214265
# (3) Biological sciences                   176760   181725   185240   189230
# (4) Veterinary science                      5085     5255     5470     5715
# (5) Agriculture & related subjects         15130    15595    15090    15035
# (6) Physical sciences                      73890    75305    75050    74805
# (7) Mathematical sciences                  36130    36715    37140    37620
# (8) Computer science                       76490    79495    83645    88025
# (9) Engineering & technology              121560   124400   126860   127345
# (A) Architecture, building & planning      33310    33920    34800    36605
# (B) Social studies                        159600   165170   170365   176940
# ...

# %% [markdown]
# ##### Top 5 subjects with highest number of students are Business, Subject allied to medicine, Biological Sciences, Social Studies, and Creative Arts & Design
# ##### Top 5 subjects with highest increase in number of students (4-year-period / percentage)  are Computer Science, Veterinary Science, Social Studies, Architecture, and Business
# ##### Top 5 subjects with highest decrease "or" lowest increase in number of students (4-year-period / percentage) are Combined, Education, Languages, Historical & Philosophical, Physical Sciences
# ##### Top 5 subjects with highest average increase rate in number of students per year are Computer Science, Veterinary Science, Social Studies, Architecture, and Business
# ##### Top 5 subjects with highest average decrease rate "or" lowest average increase rate in number of students per year are Combined, Education, Languages, Historical & Philosophical, Physical Sciences
# ##### Top 5 subjects with highest median increase rate in number of students per year are Computer Science, Veterinary Science, Social Studies, Architecture, and Business
# ##### Top 5 subjects with highest median decrease rate "or" lowest median increase rate in number of students per year are Combined, Education, Languages, Historical & Philosophical, Physical Sciences

# %% [markdown]
# ### Postgraduate in England

# %%
dfPostGradEngland = df[(df['First year marker'] == 'All') &
   (df['Mode of study'] == 'All') &
   (df['Country of HE provider'] == 'England') &
   (df['Sex'] == 'Total') &
   ((df['Level of study'] == 'All postgraduate')) &
    (~df['Subject Area'].str.startswith('Total'))]

# %%
pivotDfPostGradEngland = dfPostGradEngland.pivot_table('Number', ['Subject Area'], 'Academic Year')

# %%
pivotDfPostGradEngland.sort_values(by='2014/15', ascending=False)
# Out:
# Academic Year                            2014/15  2015/16  2016/17  2017/18  \
# Subject Area
# (D) Business & administrative studies      83565    80635    81455    85570
# (I) Education                              67465    62520    60425    58900
# (2) Subjects allied to medicine            50175    54735    59605    59705
# (B) Social studies                         42150    42135    44675    45475
# (9) Engineering & technology               32635    31900    31520    30920
# (3) Biological sciences                    28670    29565    34570    36870
# (H) Creative arts & design                 18780    19090    21840    23215
# (1) Medicine & dentistry                   16340    16525    16250    16375
# (6) Physical sciences                      15980    15680    15990    16530
# (C) Law                                    15350    15425    16105    16470
# (8) Computer science                       13815    13640    14270    15485
# ...

# %%
pivotDfPostGradEngland.sort_values(by='2015/16', ascending=False)
# Out:
# Academic Year                            2014/15  2015/16  2016/17  2017/18  \
# Subject Area
# (D) Business & administrative studies      83565    80635    81455    85570
# (I) Education                              67465    62520    60425    58900
# (2) Subjects allied to medicine            50175    54735    59605    59705
# (B) Social studies                         42150    42135    44675    45475
# (9) Engineering & technology               32635    31900    31520    30920
# (3) Biological sciences                    28670    29565    34570    36870
# (H) Creative arts & design                 18780    19090    21840    23215
# (1) Medicine & dentistry                   16340    16525    16250    16375
# (6) Physical sciences                      15980    15680    15990    16530
# (C) Law                                    15350    15425    16105    16470
# (8) Computer science                       13815    13640    14270    15485
# ...

# %%
pivotDfPostGradEngland.sort_values(by='2016/17', ascending=False)
# Out:
# Academic Year                            2014/15  2015/16  2016/17  2017/18  \
# Subject Area
# (D) Business & administrative studies      83565    80635    81455    85570
# (I) Education                              67465    62520    60425    58900
# (2) Subjects allied to medicine            50175    54735    59605    59705
# (B) Social studies                         42150    42135    44675    45475
# (3) Biological sciences                    28670    29565    34570    36870
# (9) Engineering & technology               32635    31900    31520    30920
# (H) Creative arts & design                 18780    19090    21840    23215
# (1) Medicine & dentistry                   16340    16525    16250    16375
# (C) Law                                    15350    15425    16105    16470
# (6) Physical sciences                      15980    15680    15990    16530
# (8) Computer science                       13815    13640    14270    15485
# ...

# %%
pivotDfPostGradEngland.sort_values(by='2017/18', ascending=False)
# Out:
# Academic Year                            2014/15  2015/16  2016/17  2017/18  \
# Subject Area
# (D) Business & administrative studies      83565    80635    81455    85570
# (2) Subjects allied to medicine            50175    54735    59605    59705
# (I) Education                              67465    62520    60425    58900
# (B) Social studies                         42150    42135    44675    45475
# (3) Biological sciences                    28670    29565    34570    36870
# (9) Engineering & technology               32635    31900    31520    30920
# (H) Creative arts & design                 18780    19090    21840    23215
# (6) Physical sciences                      15980    15680    15990    16530
# (C) Law                                    15350    15425    16105    16470
# (1) Medicine & dentistry                   16340    16525    16250    16375
# (8) Computer science                       13815    13640    14270    15485
# ...

# %%
pivotDfPostGradEngland.sort_values(by='2018/19', ascending=False)
# Out:
# Academic Year                            2014/15  2015/16  2016/17  2017/18  \
# Subject Area
# (D) Business & administrative studies      83565    80635    81455    85570
# (2) Subjects allied to medicine            50175    54735    59605    59705
# (I) Education                              67465    62520    60425    58900
# (B) Social studies                         42150    42135    44675    45475
# (3) Biological sciences                    28670    29565    34570    36870
# (9) Engineering & technology               32635    31900    31520    30920
# (H) Creative arts & design                 18780    19090    21840    23215
# (8) Computer science                       13815    13640    14270    15485
# (6) Physical sciences                      15980    15680    15990    16530
# (1) Medicine & dentistry                   16340    16525    16250    16375
# (C) Law                                    15350    15425    16105    16470
# ...

# %%
pivotDfPostGradEngland['%Change 14/15 to 15/16'] = ((pivotDfPostGradEngland['2015/16'] - pivotDfPostGradEngland['2014/15'])/pivotDfPostGradEngland['2014/15']) * 100
pivotDfPostGradEngland['%Change 15/16 to 16/17'] = ((pivotDfPostGradEngland['2016/17'] - pivotDfPostGradEngland['2015/16'])/pivotDfPostGradEngland['2015/16']) * 100
pivotDfPostGradEngland['%Change 16/17 to 17/18'] = ((pivotDfPostGradEngland['2017/18'] - pivotDfPostGradEngland['2016/17'])/pivotDfPostGradEngland['2016/17']) * 100
pivotDfPostGradEngland['%Change 17/18 to 18/19'] = ((pivotDfPostGradEngland['2018/19'] - pivotDfPostGradEngland['2017/18'])/pivotDfPostGradEngland['2017/18']) * 100
pivotDfPostGradEngland['%Change 14/15 to 18/19'] = ((pivotDfPostGradEngland['2018/19'] - pivotDfPostGradEngland['2014/15'])/pivotDfPostGradEngland['2014/15']) * 100
pivotDfPostGradEngland['Avg. %Change 14/15 to 18/19'] = (pivotDfPostGradEngland['%Change 14/15 to 15/16'] + pivotDfPostGradEngland['%Change 15/16 to 16/17'] + pivotDfPostGradEngland['%Change 16/17 to 17/18'] + pivotDfPostGradEngland['%Change 17/18 to 18/19']) / 4

# %%
pivotDfPostGradEngland['Median of %Change 14/15 to 18/19'] = pivotDfPostGradEngland[['%Change 14/15 to 15/16', '%Change 15/16 to 16/17', '%Change 16/17 to 17/18', '%Change 17/18 to 18/19']].median(1)

# %%
pivotDfPostGradEngland
# Out:
# Academic Year                            2014/15  2015/16  2016/17  2017/18  \
# Subject Area
# (1) Medicine & dentistry                   16340    16525    16250    16375
# (2) Subjects allied to medicine            50175    54735    59605    59705
# (3) Biological sciences                    28670    29565    34570    36870
# (4) Veterinary science                       675     1385     1520     1960
# (5) Agriculture & related subjects          2940     2310     2345     2235
# (6) Physical sciences                      15980    15680    15990    16530
# (7) Mathematical sciences                   5505     5530     5915     5925
# (8) Computer science                       13815    13640    14270    15485
# (9) Engineering & technology               32635    31900    31520    30920
# (A) Architecture, building & planning      12270    12690    13680    14050
# (B) Social studies                         42150    42135    44675    45475
# ...

# %% [markdown]
# ##### Top 5 subjects with highest number of students are Business, Subject allied to medicine, Education Social Studies, and rank 5 was changed from Engineering to Biological Science
# ##### Top 5 subjects with highest increase in number of students (4-year-period / percentage) are Veterinary Science, Biological Science, Creative Arts & Design, Computer Science, Subjects allied to Medicine
# ##### Top 5 subjects with highest decrease "or" lowest increase in number of students (4-year-period / percentage) are Combined, Education, Agriculture, Engineering & technology, Medicine & Dentistry
# ##### Top 5 subjects with highest average increase rate in number of students per year are Veterinary Science, Biological Science, Creative Arts & Design, Computer Science, Mass communications & documentation
# ##### Top 5 subjects with highest average decrease rate "or" lowest average increase rate in number of students per year are Combined, Agriculture, Education, Engineering & technology, Historical & philosophical studies
# ##### Top 5 subjects with highest median increase rate in number of students per year are Veterinary Science, Computer Science, Mass Communication, Creative Arts & Design, and Subjects allied to Medicine
# ##### Top 5 subjects with highest median decrease rate "or" lowest median increase rate in number of students per year are Combined, Education, Agriculture, Engineering, and Historical & Philosophical

# %% [markdown]
# ### Undergraduate in England

# %%
dfUnderGradEngland = df[(df['First year marker'] == 'All') &
   (df['Mode of study'] == 'All') &
   (df['Country of HE provider'] == 'England') &
   (df['Sex'] == 'Total') &
   ((df['Level of study'] == 'All undergraduate')) &
    (~df['Subject Area'].str.startswith('Total'))]

# %%
pivotDfUnderGradEngland = dfUnderGradEngland.pivot_table('Number', ['Subject Area'], 'Academic Year')

# %%
pivotDfUnderGradEngland.sort_values(by='2014/15', ascending=False)
# Out:
# Academic Year                            2014/15  2015/16  2016/17  2017/18  \
# Subject Area
# (D) Business & administrative studies     182465   188225   195400   201405
# (2) Subjects allied to medicine           176540   178925   178005   173820
# (3) Biological sciences                   141230   146690   149040   152400
# (B) Social studies                        131235   135900   140780   146455
# (H) Creative arts & design                125835   128125   131100   132415
# (9) Engineering & technology               94415    97460    99165    99640
# (F) Languages                              77465    75520    72730    68520
# (I) Education                              64440    61885    59010    56045
# (8) Computer science                       59545    62420    65635    69180
# (6) Physical sciences                      59275    59955    59820    59790
# (C) Law                                    58075    58685    58810    60525
# ...

# %%
pivotDfUnderGradEngland.sort_values(by='2015/16', ascending=False)
# Out:
# Academic Year                            2014/15  2015/16  2016/17  2017/18  \
# Subject Area
# (D) Business & administrative studies     182465   188225   195400   201405
# (2) Subjects allied to medicine           176540   178925   178005   173820
# (3) Biological sciences                   141230   146690   149040   152400
# (B) Social studies                        131235   135900   140780   146455
# (H) Creative arts & design                125835   128125   131100   132415
# (9) Engineering & technology               94415    97460    99165    99640
# (F) Languages                              77465    75520    72730    68520
# (8) Computer science                       59545    62420    65635    69180
# (I) Education                              64440    61885    59010    56045
# (6) Physical sciences                      59275    59955    59820    59790
# (C) Law                                    58075    58685    58810    60525
# ...

# %%
pivotDfUnderGradEngland.sort_values(by='2016/17', ascending=False)
# Out:
# Academic Year                            2014/15  2015/16  2016/17  2017/18  \
# Subject Area
# (D) Business & administrative studies     182465   188225   195400   201405
# (2) Subjects allied to medicine           176540   178925   178005   173820
# (3) Biological sciences                   141230   146690   149040   152400
# (B) Social studies                        131235   135900   140780   146455
# (H) Creative arts & design                125835   128125   131100   132415
# (9) Engineering & technology               94415    97460    99165    99640
# (F) Languages                              77465    75520    72730    68520
# (8) Computer science                       59545    62420    65635    69180
# (6) Physical sciences                      59275    59955    59820    59790
# (I) Education                              64440    61885    59010    56045
# (C) Law                                    58075    58685    58810    60525
# ...

# %%
pivotDfUnderGradEngland.sort_values(by='2017/18', ascending=False)
# Out:
# Academic Year                            2014/15  2015/16  2016/17  2017/18  \
# Subject Area
# (D) Business & administrative studies     182465   188225   195400   201405
# (2) Subjects allied to medicine           176540   178925   178005   173820
# (3) Biological sciences                   141230   146690   149040   152400
# (B) Social studies                        131235   135900   140780   146455
# (H) Creative arts & design                125835   128125   131100   132415
# (9) Engineering & technology               94415    97460    99165    99640
# (8) Computer science                       59545    62420    65635    69180
# (F) Languages                              77465    75520    72730    68520
# (C) Law                                    58075    58685    58810    60525
# (6) Physical sciences                      59275    59955    59820    59790
# (I) Education                              64440    61885    59010    56045
# ...

# %%
pivotDfUnderGradEngland.sort_values(by='2018/19', ascending=False)
# Out:
# Academic Year                            2014/15  2015/16  2016/17  2017/18  \
# Subject Area
# (D) Business & administrative studies     182465   188225   195400   201405
# (2) Subjects allied to medicine           176540   178925   178005   173820
# (3) Biological sciences                   141230   146690   149040   152400
# (B) Social studies                        131235   135900   140780   146455
# (H) Creative arts & design                125835   128125   131100   132415
# (9) Engineering & technology               94415    97460    99165    99640
# (8) Computer science                       59545    62420    65635    69180
# (F) Languages                              77465    75520    72730    68520
# (C) Law                                    58075    58685    58810    60525
# (6) Physical sciences                      59275    59955    59820    59790
# (I) Education                              64440    61885    59010    56045
# ...

# %%
pivotDfUnderGradEngland['%Change 14/15 to 15/16'] = ((pivotDfUnderGradEngland['2015/16'] - pivotDfUnderGradEngland['2014/15'])/pivotDfUnderGradEngland['2014/15']) * 100
pivotDfUnderGradEngland['%Change 15/16 to 16/17'] = ((pivotDfUnderGradEngland['2016/17'] - pivotDfUnderGradEngland['2015/16'])/pivotDfUnderGradEngland['2015/16']) * 100
pivotDfUnderGradEngland['%Change 16/17 to 17/18'] = ((pivotDfUnderGradEngland['2017/18'] - pivotDfUnderGradEngland['2016/17'])/pivotDfUnderGradEngland['2016/17']) * 100
pivotDfUnderGradEngland['%Change 17/18 to 18/19'] = ((pivotDfUnderGradEngland['2018/19'] - pivotDfUnderGradEngland['2017/18'])/pivotDfUnderGradEngland['2017/18']) * 100
pivotDfUnderGradEngland['%Change 14/15 to 18/19'] = ((pivotDfUnderGradEngland['2018/19'] - pivotDfUnderGradEngland['2014/15'])/pivotDfUnderGradEngland['2014/15']) * 100
pivotDfUnderGradEngland['Avg. %Change 14/15 to 18/19'] = (pivotDfUnderGradEngland['%Change 14/15 to 15/16'] + pivotDfUnderGradEngland['%Change 15/16 to 16/17'] + pivotDfUnderGradEngland['%Change 16/17 to 17/18'] + pivotDfUnderGradEngland['%Change 17/18 to 18/19']) / 4

# %%
pivotDfUnderGradEngland['Median of %Change 14/15 to 18/19'] = pivotDfUnderGradEngland[['%Change 14/15 to 15/16', '%Change 15/16 to 16/17', '%Change 16/17 to 17/18', '%Change 17/18 to 18/19']].median(1)

# %%
pivotDfUnderGradEngland
# Out:
# Academic Year                            2014/15  2015/16  2016/17  2017/18  \
# Subject Area
# (1) Medicine & dentistry                   36025    35705    35770    36510
# (2) Subjects allied to medicine           176540   178925   178005   173820
# (3) Biological sciences                   141230   146690   149040   152400
# (4) Veterinary science                      3675     3870     4085     4350
# (5) Agriculture & related subjects         12420    12780    12260    12310
# (6) Physical sciences                      59275    59955    59820    59790
# (7) Mathematical sciences                  30690    30985    31440    31805
# (8) Computer science                       59545    62420    65635    69180
# (9) Engineering & technology               94415    97460    99165    99640
# (A) Architecture, building & planning      26955    27405    28080    29670
# (B) Social studies                        131235   135900   140780   146455
# ...

# %% [markdown]
# ##### Top 5 subjects with highest number of students are Business, Subject allied to medicine, Biological Sciences, Social Studies, and Creative Arts & Design
# ##### Top 5 subjects with highest increase in number of students (4-year-period / percentage) are Veterinary Science, Computer Science, Social Studies, Business, and Architecture
# ##### Top 5 subjects with highest decrease in number of students (4-year-period / percentage) are Combined, Education, Languages, Historical & Philosophical, Subjects allied to medicine
# ##### Top 5 subjects with highest average increase rate in number of students per year are Veterinary Science, Computer Science, Social Studies, Business, and Architecture
# ##### Top 5 subjects with highest average decrease rate "or" lowest average increase rate in number of students per year are Combined, Education, Languages, Historical & Philosophical, Subjects allied to medicine
# ##### Top 5 subjects with highest median increase rate in number of students per year are Veterinary Science, Computer Science, Social Studies, Business, and Architecture
# ##### Top 5 subjects with highest median decrease rate "or" lowest median increase rate in number of students per year are Combined, Education, Languages, Historical & Philosophical, Subjects allied to medicine

# %% [markdown]
# ### Postgraduate in Wales

# %%
dfPostGradWales = df[(df['First year marker'] == 'All') &
   (df['Mode of study'] == 'All') &
   (df['Country of HE provider'] == 'Wales') &
   (df['Sex'] == 'Total') &
   ((df['Level of study'] == 'All postgraduate')) &
    (~df['Subject Area'].str.startswith('Total'))]

# %%
pivotDfPostGradWales = dfPostGradWales.pivot_table('Number', ['Subject Area'], 'Academic Year')

# %%
pivotDfPostGradWales.sort_values(by='2014/15', ascending=False)
# Out:
# Academic Year                            2014/15  2015/16  2016/17  2017/18  \
# Subject Area
# (D) Business & administrative studies       7780     5935     4995     4860
# (I) Education                               4040     3500     2955     2570
# (2) Subjects allied to medicine             3025     3225     3300     3475
# (3) Biological sciences                     2010     2010     2435     3125
# (1) Medicine & dentistry                    1630     1350     1105      975
# (9) Engineering & technology                1480     1435     1395     1330
# (B) Social studies                          1305     1550     1690     1790
# (C) Law                                     1000      950      940      940
# (H) Creative arts & design                   970      895      920     1040
# (F) Languages                                790      760      785      845
# (E) Mass communications & documentation      775      675      750      790
# ...

# %%
pivotDfPostGradWales.sort_values(by='2015/16', ascending=False)
# Out:
# Academic Year                            2014/15  2015/16  2016/17  2017/18  \
# Subject Area
# (D) Business & administrative studies       7780     5935     4995     4860
# (I) Education                               4040     3500     2955     2570
# (2) Subjects allied to medicine             3025     3225     3300     3475
# (3) Biological sciences                     2010     2010     2435     3125
# (B) Social studies                          1305     1550     1690     1790
# (9) Engineering & technology                1480     1435     1395     1330
# (1) Medicine & dentistry                    1630     1350     1105      975
# (C) Law                                     1000      950      940      940
# (H) Creative arts & design                   970      895      920     1040
# (6) Physical sciences                        740      770      845      980
# (F) Languages                                790      760      785      845
# ...

# %%
pivotDfPostGradWales.sort_values(by='2016/17', ascending=False)
# Out:
# Academic Year                            2014/15  2015/16  2016/17  2017/18  \
# Subject Area
# (D) Business & administrative studies       7780     5935     4995     4860
# (2) Subjects allied to medicine             3025     3225     3300     3475
# (I) Education                               4040     3500     2955     2570
# (3) Biological sciences                     2010     2010     2435     3125
# (B) Social studies                          1305     1550     1690     1790
# (9) Engineering & technology                1480     1435     1395     1330
# (1) Medicine & dentistry                    1630     1350     1105      975
# (C) Law                                     1000      950      940      940
# (H) Creative arts & design                   970      895      920     1040
# (6) Physical sciences                        740      770      845      980
# (F) Languages                                790      760      785      845
# ...

# %%
pivotDfPostGradWales.sort_values(by='2017/18', ascending=False)
# Out:
# Academic Year                            2014/15  2015/16  2016/17  2017/18  \
# Subject Area
# (D) Business & administrative studies       7780     5935     4995     4860
# (2) Subjects allied to medicine             3025     3225     3300     3475
# (3) Biological sciences                     2010     2010     2435     3125
# (I) Education                               4040     3500     2955     2570
# (B) Social studies                          1305     1550     1690     1790
# (9) Engineering & technology                1480     1435     1395     1330
# (H) Creative arts & design                   970      895      920     1040
# (6) Physical sciences                        740      770      845      980
# (1) Medicine & dentistry                    1630     1350     1105      975
# (C) Law                                     1000      950      940      940
# (F) Languages                                790      760      785      845
# ...

# %%
pivotDfPostGradWales.sort_values(by='2018/19', ascending=False)
# Out:
# Academic Year                            2014/15  2015/16  2016/17  2017/18  \
# Subject Area
# (D) Business & administrative studies       7780     5935     4995     4860
# (2) Subjects allied to medicine             3025     3225     3300     3475
# (3) Biological sciences                     2010     2010     2435     3125
# (I) Education                               4040     3500     2955     2570
# (B) Social studies                          1305     1550     1690     1790
# (9) Engineering & technology                1480     1435     1395     1330
# (H) Creative arts & design                   970      895      920     1040
# (C) Law                                     1000      950      940      940
# (6) Physical sciences                        740      770      845      980
# (1) Medicine & dentistry                    1630     1350     1105      975
# (E) Mass communications & documentation      775      675      750      790
# ...

# %%
pivotDfPostGradWales['%Change 14/15 to 15/16'] = ((pivotDfPostGradWales['2015/16'] - pivotDfPostGradWales['2014/15'])/pivotDfPostGradWales['2014/15']) * 100
pivotDfPostGradWales['%Change 15/16 to 16/17'] = ((pivotDfPostGradWales['2016/17'] - pivotDfPostGradWales['2015/16'])/pivotDfPostGradWales['2015/16']) * 100
pivotDfPostGradWales['%Change 16/17 to 17/18'] = ((pivotDfPostGradWales['2017/18'] - pivotDfPostGradWales['2016/17'])/pivotDfPostGradWales['2016/17']) * 100
pivotDfPostGradWales['%Change 17/18 to 18/19'] = ((pivotDfPostGradWales['2018/19'] - pivotDfPostGradWales['2017/18'])/pivotDfPostGradWales['2017/18']) * 100
pivotDfPostGradWales['%Change 14/15 to 18/19'] = ((pivotDfPostGradWales['2018/19'] - pivotDfPostGradWales['2014/15'])/pivotDfPostGradWales['2014/15']) * 100
pivotDfPostGradWales['Avg. %Change 14/15 to 18/19'] = (pivotDfPostGradWales['%Change 14/15 to 15/16'] + pivotDfPostGradWales['%Change 15/16 to 16/17'] + pivotDfPostGradWales['%Change 16/17 to 17/18'] + pivotDfPostGradWales['%Change 17/18 to 18/19']) / 4

# %%
pivotDfPostGradWales['Median of %Change 14/15 to 18/19'] = pivotDfPostGradWales[['%Change 14/15 to 15/16', '%Change 15/16 to 16/17', '%Change 16/17 to 17/18', '%Change 17/18 to 18/19']].median(1)

# %%
pivotDfPostGradWales
# Out:
# Academic Year                            2014/15  2015/16  2016/17  2017/18  \
# Subject Area
# (1) Medicine & dentistry                    1630     1350     1105      975
# (2) Subjects allied to medicine             3025     3225     3300     3475
# (3) Biological sciences                     2010     2010     2435     3125
# (5) Agriculture & related subjects           305      285      320      315
# (6) Physical sciences                        740      770      845      980
# (7) Mathematical sciences                    150      160      165      185
# (8) Computer science                         725      565      550      675
# (9) Engineering & technology                1480     1435     1395     1330
# (A) Architecture, building & planning        505      510      490      530
# (B) Social studies                          1305     1550     1690     1790
# (C) Law                                     1000      950      940      940
# ...

# %% [markdown]
# ##### Top 5 subjects with highest number of students  are Business, Subject allied to medicine, Biological Sciences, Social Studies, and Education. However, Medicine & Dentistry is used to be rank 5 in 2014/15 before falling to 2018/19
# ##### Top 5 subjects with highest increase in number of students (4-year-period / percentage) are Mathematical sciences, Biological sciences, Social Studies, Physical sciences, and Subjects allied to medicine
# ##### Top 5 subjects with highest decrease "or" lowest increase in number of students (4-year-period / percentage) are Combined, Medicine & Dentistry, Education, Business, and Agriculture
# ##### Top 5 subjects with highest average increase rate in number of students per year are Combined, Mathematical sciences, Biological sciences, Social Studies, and Physical Studies
# ##### Top 5 subjects with highest average decrease rate "or" lowest average increase rate in number of students per year are Education, Medicine & Dentistry, Business, Agriculture, and Engineering
# ##### Top 5 subjects with highest median increase rate in number of students per year are Biological sciences, Social Studies, Computer Science, Math, and Mass Communication & Documentary
# ##### Top 5 subjects with highest median decrease rate "or" lowest median increase rate in number of students per year are Combined, Medicine & Dentistry, Education, Business, and Agriculture

# %% [markdown]
# # Important: we will see from the data displayed above that, using different measures may result in different rankings (significantly)!

# %% [markdown]
# ### Undergraduate in Wales

# %%
dfUnderGradWales = df[(df['First year marker'] == 'All') &
   (df['Mode of study'] == 'All') &
   (df['Country of HE provider'] == 'Wales') &
   (df['Sex'] == 'Total') &
   ((df['Level of study'] == 'All undergraduate')) &
    (~df['Subject Area'].str.startswith('Total'))]

# %%
pivotDfUnderGradWales = dfUnderGradWales.pivot_table('Number', ['Subject Area'], 'Academic Year')

# %%
pivotDfUnderGradWales.sort_values(by='2014/15', ascending=False)
# Out:
# Academic Year                            2014/15  2015/16  2016/17  2017/18  \
# Subject Area
# (3) Biological sciences                    13980    13455    13850    13935
# (D) Business & administrative studies      12080    11175    11590    10420
# (2) Subjects allied to medicine             9575    10945    11180    11775
# (9) Engineering & technology                8915     8355     8620     8535
# (B) Social studies                          8390     9000     9605     9780
# (I) Education                               8020     7935     7115     5930
# (H) Creative arts & design                  7625     7570     7470     7540
# (F) Languages                               6800     6740     6620     6715
# (J) Combined                                5350     3835     4005     5360
# (6) Physical sciences                       4940     5040     5040     4810
# (8) Computer science                        4630     4600     4845     4910
# ...

# %%
pivotDfUnderGradWales.sort_values(by='2015/16', ascending=False)
# Out:
# Academic Year                            2014/15  2015/16  2016/17  2017/18  \
# Subject Area
# (3) Biological sciences                    13980    13455    13850    13935
# (D) Business & administrative studies      12080    11175    11590    10420
# (2) Subjects allied to medicine             9575    10945    11180    11775
# (B) Social studies                          8390     9000     9605     9780
# (9) Engineering & technology                8915     8355     8620     8535
# (I) Education                               8020     7935     7115     5930
# (H) Creative arts & design                  7625     7570     7470     7540
# (F) Languages                               6800     6740     6620     6715
# (6) Physical sciences                       4940     5040     5040     4810
# (8) Computer science                        4630     4600     4845     4910
# (J) Combined                                5350     3835     4005     5360
# ...

# %%
pivotDfUnderGradWales.sort_values(by='2016/17', ascending=False)
# Out:
# Academic Year                            2014/15  2015/16  2016/17  2017/18  \
# Subject Area
# (3) Biological sciences                    13980    13455    13850    13935
# (D) Business & administrative studies      12080    11175    11590    10420
# (2) Subjects allied to medicine             9575    10945    11180    11775
# (B) Social studies                          8390     9000     9605     9780
# (9) Engineering & technology                8915     8355     8620     8535
# (H) Creative arts & design                  7625     7570     7470     7540
# (I) Education                               8020     7935     7115     5930
# (F) Languages                               6800     6740     6620     6715
# (6) Physical sciences                       4940     5040     5040     4810
# (8) Computer science                        4630     4600     4845     4910
# (J) Combined                                5350     3835     4005     5360
# ...

# %%
pivotDfUnderGradWales.sort_values(by='2017/18', ascending=False)
# Out:
# Academic Year                            2014/15  2015/16  2016/17  2017/18  \
# Subject Area
# (3) Biological sciences                    13980    13455    13850    13935
# (2) Subjects allied to medicine             9575    10945    11180    11775
# (D) Business & administrative studies      12080    11175    11590    10420
# (B) Social studies                          8390     9000     9605     9780
# (9) Engineering & technology                8915     8355     8620     8535
# (H) Creative arts & design                  7625     7570     7470     7540
# (F) Languages                               6800     6740     6620     6715
# (I) Education                               8020     7935     7115     5930
# (J) Combined                                5350     3835     4005     5360
# (8) Computer science                        4630     4600     4845     4910
# (6) Physical sciences                       4940     5040     5040     4810
# ...

# %%
pivotDfUnderGradWales.sort_values(by='2018/19', ascending=False)
# Out:
# Academic Year                            2014/15  2015/16  2016/17  2017/18  \
# Subject Area
# (3) Biological sciences                    13980    13455    13850    13935
# (2) Subjects allied to medicine             9575    10945    11180    11775
# (D) Business & administrative studies      12080    11175    11590    10420
# (B) Social studies                          8390     9000     9605     9780
# (9) Engineering & technology                8915     8355     8620     8535
# (H) Creative arts & design                  7625     7570     7470     7540
# (F) Languages                               6800     6740     6620     6715
# (I) Education                               8020     7935     7115     5930
# (8) Computer science                        4630     4600     4845     4910
# (J) Combined                                5350     3835     4005     5360
# (6) Physical sciences                       4940     5040     5040     4810
# ...

# %%
pivotDfUnderGradWales['%Change 14/15 to 15/16'] = ((pivotDfUnderGradWales['2015/16'] - pivotDfUnderGradWales['2014/15'])/pivotDfUnderGradWales['2014/15']) * 100
pivotDfUnderGradWales['%Change 15/16 to 16/17'] = ((pivotDfUnderGradWales['2016/17'] - pivotDfUnderGradWales['2015/16'])/pivotDfUnderGradWales['2015/16']) * 100
pivotDfUnderGradWales['%Change 16/17 to 17/18'] = ((pivotDfUnderGradWales['2017/18'] - pivotDfUnderGradWales['2016/17'])/pivotDfUnderGradWales['2016/17']) * 100
pivotDfUnderGradWales['%Change 17/18 to 18/19'] = ((pivotDfUnderGradWales['2018/19'] - pivotDfUnderGradWales['2017/18'])/pivotDfUnderGradWales['2017/18']) * 100
pivotDfUnderGradWales['%Change 14/15 to 18/19'] = ((pivotDfUnderGradWales['2018/19'] - pivotDfUnderGradWales['2014/15'])/pivotDfUnderGradWales['2014/15']) * 100
pivotDfUnderGradWales['Avg. %Change 14/15 to 18/19'] = (pivotDfUnderGradWales['%Change 14/15 to 15/16'] + pivotDfUnderGradWales['%Change 15/16 to 16/17'] + pivotDfUnderGradWales['%Change 16/17 to 17/18'] + pivotDfUnderGradWales['%Change 17/18 to 18/19']) / 4

# %%
pivotDfUnderGradWales['Median of %Change 14/15 to 18/19'] = pivotDfUnderGradWales[['%Change 14/15 to 15/16', '%Change 15/16 to 16/17', '%Change 16/17 to 17/18', '%Change 17/18 to 18/19']].median(1)

# %%
pivotDfUnderGradWales
# Out:
# Academic Year                            2014/15  2015/16  2016/17  2017/18  \
# Subject Area
# (1) Medicine & dentistry                    2215     2220     2260     2205
# (2) Subjects allied to medicine             9575    10945    11180    11775
# (3) Biological sciences                    13980    13455    13850    13935
# (5) Agriculture & related subjects          1055     1065     1020     1000
# (6) Physical sciences                       4940     5040     5040     4810
# (7) Mathematical sciences                   1460     1445     1465     1410
# (8) Computer science                        4630     4600     4845     4910
# (9) Engineering & technology                8915     8355     8620     8535
# (A) Architecture, building & planning       1405     1540     1620     1605
# (B) Social studies                          8390     9000     9605     9780
# (C) Law                                     3015     3105     3200     3270
# ...

# %% [markdown]
# ##### Top 5 subjects with highest number of students are Biological Sciences, Subject allied to medicine, Business, Social Studies, and Engineering.
# ##### Top 5 subjects with highest increase in number of students (4-year-period / percentage) are Social Studies, Subjects allied to medicine, Architecture, Computer Science, and Law
# ##### Top 5 subjects with highest decrease "or" lowest increase in number of students (4-year-period / percentage) are Education, Historical & philosophical, Engineering, Business, and Languages
# ##### Top 5 subjects with highest average increase rate in number of students per year are Social Studies, Subjects allied to medicine, Architecture, Computer Science, and Law
# ##### Top 5 subjects with highest average decrease rate "or" lowest average increase rate in number of students per year are Education, Historical & philosophical, Engineering, Business, and Languages
# ##### Top 5 subjects with highest median increase rate in number of students per year are Social Studies, Subjects allied to medicine, Computer Science, Architecture, and Law
# ##### Top 5 subjects with highest median decrease rate "or" lowest median increase rate in number of students per year are Education, Historical & philosophical, Engineering, Business, and Languages

# %% [markdown]
# ### Postgraduate in Northern Ireland

# %%
dfPostGradNI = df[(df['First year marker'] == 'All') &
   (df['Mode of study'] == 'All') &
   (df['Country of HE provider'] == 'Northern Ireland') &
   (df['Sex'] == 'Total') &
   ((df['Level of study'] == 'All postgraduate')) &
    (~df['Subject Area'].str.startswith('Total'))]

# %%
pivotDfPostGradNI = dfPostGradNI.pivot_table('Number', ['Subject Area'], 'Academic Year')

# %%
pivotDfPostGradNI.sort_values(by='2014/15', ascending=False)
# Out:
# Academic Year                            2014/15  2015/16  2016/17  2017/18  \
# Subject Area
# (I) Education                               1860     1450     1390     1500
# (2) Subjects allied to medicine             1845     1890     2100     2100
# (D) Business & administrative studies       1485     1375     1540     1740
# (B) Social studies                          1120     1110     1080     1145
# (3) Biological sciences                      745      685      625      755
# (6) Physical sciences                        610      630      600      605
# (C) Law                                      610      575      570      580
# (9) Engineering & technology                 525      515      545      600
# (1) Medicine & dentistry                     485      505      490      565
# (A) Architecture, building & planning        370      375      445      450
# (8) Computer science                         365      335      280      335
# ...

# %%
pivotDfPostGradNI.sort_values(by='2015/16', ascending=False)
# Out:
# Academic Year                            2014/15  2015/16  2016/17  2017/18  \
# Subject Area
# (2) Subjects allied to medicine             1845     1890     2100     2100
# (I) Education                               1860     1450     1390     1500
# (D) Business & administrative studies       1485     1375     1540     1740
# (B) Social studies                          1120     1110     1080     1145
# (3) Biological sciences                      745      685      625      755
# (6) Physical sciences                        610      630      600      605
# (C) Law                                      610      575      570      580
# (9) Engineering & technology                 525      515      545      600
# (1) Medicine & dentistry                     485      505      490      565
# (A) Architecture, building & planning        370      375      445      450
# (8) Computer science                         365      335      280      335
# ...

# %%
pivotDfPostGradNI.sort_values(by='2016/17', ascending=False)
# Out:
# Academic Year                            2014/15  2015/16  2016/17  2017/18  \
# Subject Area
# (2) Subjects allied to medicine             1845     1890     2100     2100
# (D) Business & administrative studies       1485     1375     1540     1740
# (I) Education                               1860     1450     1390     1500
# (B) Social studies                          1120     1110     1080     1145
# (3) Biological sciences                      745      685      625      755
# (6) Physical sciences                        610      630      600      605
# (C) Law                                      610      575      570      580
# (9) Engineering & technology                 525      515      545      600
# (1) Medicine & dentistry                     485      505      490      565
# (A) Architecture, building & planning        370      375      445      450
# (H) Creative arts & design                   350      330      330      300
# ...

# %%
pivotDfPostGradNI.sort_values(by='2017/18', ascending=False)
# Out:
# Academic Year                            2014/15  2015/16  2016/17  2017/18  \
# Subject Area
# (2) Subjects allied to medicine             1845     1890     2100     2100
# (D) Business & administrative studies       1485     1375     1540     1740
# (I) Education                               1860     1450     1390     1500
# (B) Social studies                          1120     1110     1080     1145
# (3) Biological sciences                      745      685      625      755
# (6) Physical sciences                        610      630      600      605
# (9) Engineering & technology                 525      515      545      600
# (C) Law                                      610      575      570      580
# (1) Medicine & dentistry                     485      505      490      565
# (A) Architecture, building & planning        370      375      445      450
# (8) Computer science                         365      335      280      335
# ...

# %%
pivotDfPostGradNI.sort_values(by='2018/19', ascending=False)
# Out:
# Academic Year                            2014/15  2015/16  2016/17  2017/18  \
# Subject Area
# (2) Subjects allied to medicine             1845     1890     2100     2100
# (D) Business & administrative studies       1485     1375     1540     1740
# (I) Education                               1860     1450     1390     1500
# (B) Social studies                          1120     1110     1080     1145
# (3) Biological sciences                      745      685      625      755
# (C) Law                                      610      575      570      580
# (9) Engineering & technology                 525      515      545      600
# (6) Physical sciences                        610      630      600      605
# (1) Medicine & dentistry                     485      505      490      565
# (8) Computer science                         365      335      280      335
# (A) Architecture, building & planning        370      375      445      450
# ...

# %%
pivotDfPostGradNI['%Change 14/15 to 15/16'] = ((pivotDfPostGradNI['2015/16'] - pivotDfPostGradNI['2014/15'])/pivotDfPostGradNI['2014/15']) * 100
pivotDfPostGradNI['%Change 15/16 to 16/17'] = ((pivotDfPostGradNI['2016/17'] - pivotDfPostGradNI['2015/16'])/pivotDfPostGradNI['2015/16']) * 100
pivotDfPostGradNI['%Change 16/17 to 17/18'] = ((pivotDfPostGradNI['2017/18'] - pivotDfPostGradNI['2016/17'])/pivotDfPostGradNI['2016/17']) * 100
pivotDfPostGradNI['%Change 17/18 to 18/19'] = ((pivotDfPostGradNI['2018/19'] - pivotDfPostGradNI['2017/18'])/pivotDfPostGradNI['2017/18']) * 100
pivotDfPostGradNI['%Change 14/15 to 18/19'] = ((pivotDfPostGradNI['2018/19'] - pivotDfPostGradNI['2014/15'])/pivotDfPostGradNI['2014/15']) * 100
pivotDfPostGradNI['Avg. %Change 14/15 to 18/19'] = (pivotDfPostGradNI['%Change 14/15 to 15/16'] + pivotDfPostGradNI['%Change 15/16 to 16/17'] + pivotDfPostGradNI['%Change 16/17 to 17/18'] + pivotDfPostGradNI['%Change 17/18 to 18/19']) / 4

# %%
pivotDfPostGradNI
# Out:
# Academic Year                            2014/15  2015/16  2016/17  2017/18  \
# Subject Area
# (1) Medicine & dentistry                     485      505      490      565
# (2) Subjects allied to medicine             1845     1890     2100     2100
# (3) Biological sciences                      745      685      625      755
# (5) Agriculture & related subjects           165      140      135      150
# (6) Physical sciences                        610      630      600      605
# (7) Mathematical sciences                     15       20       20       50
# (8) Computer science                         365      335      280      335
# (9) Engineering & technology                 525      515      545      600
# (A) Architecture, building & planning        370      375      445      450
# (B) Social studies                          1120     1110     1080     1145
# (C) Law                                      610      575      570      580
# ...

# %% [markdown]
# ##### Top 5 subjects with highest number of students are Biological Sciences, Subject allied to medicine, Business, Social Studies, and Education.
# ##### Top 5 subjects with highest increase in number of students (4-year-period / percentage) are Math, Languages, Business, Subjects allied to medicine, and Engineering
# ##### Top 5 subjects with highest decrease in number of students (4-year-period / percentage) are Education, Combined, Agriculture, Creative Arts & Design, Physical Science
# ##### Top 5 subjects with highest average increase rate in number of students per year are  Math, Languages, Business, Subjects allied to medicine, and Engineering
# ##### Top 5 subjects with highest average decrease rate "or" lowest average increase rate in number of students per year are Education, Agriculture, Creative Arts & Design, Physical Science, and Historical & philosophical

# %% [markdown]
# ### Undergraduate in Northern Ireland

# %%
dfUnderGradNI = df[(df['First year marker'] == 'All') &
   (df['Mode of study'] == 'All') &
   (df['Country of HE provider'] == 'Northern Ireland') &
   (df['Sex'] == 'Total') &
   ((df['Level of study'] == 'All undergraduate')) &
    (~df['Subject Area'].str.startswith('Total'))]

# %%
pivotDfUnderGradNI = dfUnderGradNI.pivot_table('Number', ['Subject Area'], 'Academic Year')

# %%
pivotDfUnderGradNI.sort_values(by='2014/15', ascending=False)
# Out:
# Academic Year                            2014/15  2015/16  2016/17  2017/18  \
# Subject Area
# (D) Business & administrative studies       6785     6320     5980     5760
# (2) Subjects allied to medicine             5900     6070     6420     6495
# (I) Education                               4890     4970     4920     4860
# (8) Computer science                        3790     3950     3960     4025
# (B) Social studies                          3710     3675     3545     3510
# (9) Engineering & technology                3205     3240     3290     3275
# (3) Biological sciences                     3100     3115     2940     2860
# (H) Creative arts & design                  1975     1940     1825     1735
# (F) Languages                               1710     1700     1600     1440
# (J) Combined                                1675     1315      895      740
# (1) Medicine & dentistry                    1590     1590     1595     1595
# ...

# %%
pivotDfUnderGradNI.sort_values(by='2015/16', ascending=False)
# Out:
# Academic Year                            2014/15  2015/16  2016/17  2017/18  \
# Subject Area
# (D) Business & administrative studies       6785     6320     5980     5760
# (2) Subjects allied to medicine             5900     6070     6420     6495
# (I) Education                               4890     4970     4920     4860
# (8) Computer science                        3790     3950     3960     4025
# (B) Social studies                          3710     3675     3545     3510
# (9) Engineering & technology                3205     3240     3290     3275
# (3) Biological sciences                     3100     3115     2940     2860
# (H) Creative arts & design                  1975     1940     1825     1735
# (F) Languages                               1710     1700     1600     1440
# (1) Medicine & dentistry                    1590     1590     1595     1595
# (C) Law                                     1460     1530     1680     1630
# ...

# %%
pivotDfUnderGradNI.sort_values(by='2016/17', ascending=False)
# Out:
# Academic Year                            2014/15  2015/16  2016/17  2017/18  \
# Subject Area
# (2) Subjects allied to medicine             5900     6070     6420     6495
# (D) Business & administrative studies       6785     6320     5980     5760
# (I) Education                               4890     4970     4920     4860
# (8) Computer science                        3790     3950     3960     4025
# (B) Social studies                          3710     3675     3545     3510
# (9) Engineering & technology                3205     3240     3290     3275
# (3) Biological sciences                     3100     3115     2940     2860
# (H) Creative arts & design                  1975     1940     1825     1735
# (C) Law                                     1460     1530     1680     1630
# (F) Languages                               1710     1700     1600     1440
# (1) Medicine & dentistry                    1590     1590     1595     1595
# ...

# %%
pivotDfUnderGradNI.sort_values(by='2017/18', ascending=False)
# Out:
# Academic Year                            2014/15  2015/16  2016/17  2017/18  \
# Subject Area
# (2) Subjects allied to medicine             5900     6070     6420     6495
# (D) Business & administrative studies       6785     6320     5980     5760
# (I) Education                               4890     4970     4920     4860
# (8) Computer science                        3790     3950     3960     4025
# (B) Social studies                          3710     3675     3545     3510
# (9) Engineering & technology                3205     3240     3290     3275
# (3) Biological sciences                     3100     3115     2940     2860
# (H) Creative arts & design                  1975     1940     1825     1735
# (C) Law                                     1460     1530     1680     1630
# (1) Medicine & dentistry                    1590     1590     1595     1595
# (F) Languages                               1710     1700     1600     1440
# ...

# %%
pivotDfUnderGradNI.sort_values(by='2018/19', ascending=False)
# Out:
# Academic Year                            2014/15  2015/16  2016/17  2017/18  \
# Subject Area
# (2) Subjects allied to medicine             5900     6070     6420     6495
# (D) Business & administrative studies       6785     6320     5980     5760
# (I) Education                               4890     4970     4920     4860
# (8) Computer science                        3790     3950     3960     4025
# (B) Social studies                          3710     3675     3545     3510
# (9) Engineering & technology                3205     3240     3290     3275
# (3) Biological sciences                     3100     3115     2940     2860
# (C) Law                                     1460     1530     1680     1630
# (H) Creative arts & design                  1975     1940     1825     1735
# (1) Medicine & dentistry                    1590     1590     1595     1595
# (F) Languages                               1710     1700     1600     1440
# ...

# %%
pivotDfUnderGradNI['%Change 14/15 to 15/16'] = ((pivotDfUnderGradNI['2015/16'] - pivotDfUnderGradNI['2014/15'])/pivotDfUnderGradNI['2014/15']) * 100
pivotDfUnderGradNI['%Change 15/16 to 16/17'] = ((pivotDfUnderGradNI['2016/17'] - pivotDfUnderGradNI['2015/16'])/pivotDfUnderGradNI['2015/16']) * 100
pivotDfUnderGradNI['%Change 16/17 to 17/18'] = ((pivotDfUnderGradNI['2017/18'] - pivotDfUnderGradNI['2016/17'])/pivotDfUnderGradNI['2016/17']) * 100
pivotDfUnderGradNI['%Change 17/18 to 18/19'] = ((pivotDfUnderGradNI['2018/19'] - pivotDfUnderGradNI['2017/18'])/pivotDfUnderGradNI['2017/18']) * 100
pivotDfUnderGradNI['%Change 14/15 to 18/19'] = ((pivotDfUnderGradNI['2018/19'] - pivotDfUnderGradNI['2014/15'])/pivotDfUnderGradNI['2014/15']) * 100
pivotDfUnderGradNI['Avg. %Change 14/15 to 18/19'] = (pivotDfUnderGradNI['%Change 14/15 to 15/16'] + pivotDfUnderGradNI['%Change 15/16 to 16/17'] + pivotDfUnderGradNI['%Change 16/17 to 17/18'] + pivotDfUnderGradNI['%Change 17/18 to 18/19']) / 4

# %%
pivotDfUnderGradNI
# Out:
# Academic Year                            2014/15  2015/16  2016/17  2017/18  \
# Subject Area
# (1) Medicine & dentistry                    1590     1590     1595     1595
# (2) Subjects allied to medicine             5900     6070     6420     6495
# (3) Biological sciences                     3100     3115     2940     2860
# (5) Agriculture & related subjects           485      465      455      325
# (6) Physical sciences                       1130     1130     1110     1110
# (7) Mathematical sciences                    545      550      550      535
# (8) Computer science                        3790     3950     3960     4025
# (9) Engineering & technology                3205     3240     3290     3275
# (A) Architecture, building & planning       1220     1170     1135     1165
# (B) Social studies                          3710     3675     3545     3510
# (C) Law                                     1460     1530     1680     1630
# ...

# %% [markdown]
# #### >>> After 4 years passed, We can see decreasing number of students in 12 from 18 subject areas! <<<
#
# ##### Top 5 subjects with highest number of students are Subject allied to medicine, Business, Education, Computer Science, and Social Studies
# ##### Top 5 subjects with highest increase in number of students (4-year-period / percentage) are Law, Subject allied to medicine, Mass Communication & Documentation, Computer Science, and Engineering
# ##### Top 5 subjects with highest decrease in number of students (4-year-period / percentage) are Combined, Historical & philosophical, Agriculture, Languages, Business
# ##### Top 5 subjects with highest average increase rate in number of students per year are Law, Mass Communication & Documentation, Subject allied to medicine, Computer Science, and Engineering
# ##### Top 5 subjects with highest average decrease rate "or" lowest average increase rate in number of students per year are Combined, Historical & philosophical, Languages, Agriculture, Business
